# %% [markdown]
# # Code demo 280/04/2021 Flagship

# %% [markdown]
# ######

# %%
pwd

# %% [markdown]
# - petit discours d'introduction

# %%
# Import des librairies

import os
import pandas as pd
import psycopg2
import csv
import reprlib
import numpy
import re
import json

# %% [markdown]
# ######

# %% [markdown]
# -----------------------

# %% [markdown]
# ### Création de la Base de données

# %%
"""
Connexion dans un premier temps à postgres
pour initialiser notre database collection
"""


# initialisation des variables  de connection
utilisateur = "postgres"

mot_passe = os.environ.get('pg_psw')

base_de_donnees = "postgres"



try:
    
    # création de l'objet conn

    conn = psycopg2.connect(dbname= base_de_donnees, user=utilisateur, password=mot_passe, host="localhost", port= 5432)

    conn.set_session(autocommit=True)   # on force

    # initialisation du cursor

    cursor = conn.cursor()

    # cursor.execute permet d'exécuter une commande 'sql'

    cursor.execute("CREATE DATABASE collection3")

    print("La DataBase à été créée avec succès !")

        
except psycopg2.Error as e:
    
    print("Problème lors de la connection à la base de donnée")

    print(e)

   
    
finally:
        
    # ferme le curseur et devient inutilisable

    cursor.close

    # ferme la connexion à database

    conn.close

# %% [markdown]
# ######

# %%
# Cellule pour nos fonctions de connection

# Fonction qui va nous permettre de créer une Base de données.
def ouvrir_connection(base_de_donnee, utilisateur, mot_passe, host='localhost', port=5432):
    
    try:
        # création de l'objet conn
        conn = psycopg2.connect(dbname= base_de_donnee, user=utilisateur, password = mot_passe, host="localhost", port= 5432)

        # on force la sauvegarde
        conn.set_session(autocommit=True)   
        
        # initialisation du cursor
        cursor = conn.cursor()
        
        # exécution de la requête sql de création de la base de donnée
        #cursor.execute("CREATE DATABASE IF NOT EXISTS movie")

    # gestion des erreurs    
    except psycopg2.Error as e:
        print("Problème lors de la connection à la base de donnée")
        print(e)
        return None
    # dans tous les cas on va clôturer la session
    finally:
        cursor.close
        conn.close
    return conn
   
    # fonction pour supprimer une table
def supprimer_table(conn, sql_suppression_table):
    try:
        cursor = conn.cursor()
        cursor.execute(sql_suppression_table)
        conn.commit()
    except psycopg2.Error as e:
        print("Erreur lors de la suppression de la table")
        print(e)
        return
    cursor.close()
    print("La table a été supprimée avec succès")

# fonction pour créer une table    
def creer_table(conn, sql_creer_table):
    try:
        cursor = conn.cursor()
        cursor.execute(sql_creer_table)
        conn.commit()
    except psycopg2.Error as e:
        print("Erreur lors de la création de la table")
        print(e)
        return
    cursor.close()
    print("La table a été crée avec succès")

# fonction de lecture de la table    
def lire_table(conn, sql_lire_donnee):
    try:
        cursor = conn.cursor()
        cursor.execute(sql_lire_donnee)
        conn.commit()
    except psycopg2.Error as e:
        print("Erreur lors de la lecture des données")
        print(e)
        return None
    
    print("Les données ont été lues avec succès")
    
    data = []
    for row in cursor:
        data.append(row)

    cursor.close()
    
    return data

# %%
"""cellule qui content différentes requêtes sql
"""

# requète création table d'origine
sql_creer_table1 = """CREATE TABLE IF NOT EXISTS Origine(
   Code_Origine SERIAL,
   Nom VARCHAR(100),
   PRIMARY KEY(Code_Origine)
);
"""
# requète création table producteur
sql_creer_table2 = """CREATE TABLE IF NOT EXISTS Producteur(
   Code_producteur SERIAL,
   Nom VARCHAR(100),
   Code_Origine INT,
   PRIMARY KEY(Code_producteur),
   FOREIGN KEY(Code_Origine) REFERENCES Origine(Code_Origine)
);
"""
# requète création table produit
sql_creer_table3 = """CREATE TABLE IF NOT EXISTS Produit(
   Code_produit SERIAL,
   Nom VARCHAR(250),
   Volume INT,
   Degre DECIMAL(15,2),
   Code_producteur INT,
   PRIMARY KEY(Code_produit),
   FOREIGN KEY(Code_producteur) REFERENCES Producteur(Code_producteur)
);
"""
# requète lecture des données
sql_lire_donnee = """
    SELECT *
    FROM Produit
    LIMIT 10;
"""

# %%
# initialisation des variables pour me connecter à ma bdd postgres

base_de_donnee = "collection3"

utilisateur = "postgres"

mot_passe = os.environ.get('pg_psw')

# %%
# initialisation de ma connection
conn = ouvrir_connection(base_de_donnee, utilisateur, mot_passe)

# %%
# création table origine
creer_table(conn, sql_creer_table1)
# Out:
# La table a été crée avec succès

# %%
# création table origine
creer_table(conn, sql_creer_table2)
# Out:
# La table a été crée avec succès

# %%
# création table origine
creer_table(conn, sql_creer_table3)
# Out:
# La table a été crée avec succès

# %% [markdown]
# ######

# %% [markdown]
# --------------------------

# %% [markdown]
# ### Nettoyage des données

# %% [markdown]
# ######

# %% [markdown]
# - nettoyage fichier excel

# %%
excel_file = 'INVENTAIRE_A.xlsx'
inventaire = pd.read_excel(excel_file, skiprows=2)
inventaire.drop(99,0,inplace=True)
inventaire.drop(0,0,inplace=True)
del inventaire['Unnamed: 5']
inventaire.columns = ['NOM', 'VOLUME', 'DEGRE', 'NOMBRE', 'PRIX', 'MARQUE']
index_with_nan = inventaire.index[inventaire.isnull().any(axis=1)]
inventaire.drop(index_with_nan,0, inplace=True)
inventaire
# Out:
#                            NOM  VOLUME  DEGRE  NOMBRE  PRIX       MARQUE
# 1                       C12 70    70.0   50.0     5.0   8.5          HSE
# 2                       C16 70    70.0   50.0     1.0  11.0          HSE
# 3                      C16 100   100.0   50.0     1.0  14.0          HSE
# 4               PARCELLAIRE 70    70.0   55.0     2.0  13.0          HSE
# 5              PARCELLAIRE 100   100.0   55.0     1.0  15.0          HSE
# ..                         ...     ...    ...     ...   ...          ...
# 93    DOMINUS 10 years-01/2018    70.0   56.0     1.0  25.0   Foursquare
# 95  BOLOGNE BLACK CANE N°19658    70.0   50.0     1.0  21.0      Bologne
# 96  BOLOGNE BLACK CANE N°19742    70.0   50.0     1.0  21.0      Bologne
# 97      BARBANCOURT VSOP 4 ans    70.0   40.0     1.0  21.0  Barbancourt
# 98            MONTEBELLO 8 ANS    70.0   42.0     1.0  28.0   Montebello
#
# [86 rows x 6 columns]

# %%
inventaire.info
# Out:
# <bound method DataFrame.info of                            NOM  VOLUME  DEGRE  NOMBRE  PRIX       MARQUE
# 1                       C12 70    70.0   50.0     5.0   8.5          HSE
# 2                       C16 70    70.0   50.0     1.0  11.0          HSE
# 3                      C16 100   100.0   50.0     1.0  14.0          HSE
# 4               PARCELLAIRE 70    70.0   55.0     2.0  13.0          HSE
# 5              PARCELLAIRE 100   100.0   55.0     1.0  15.0          HSE
# ..                         ...     ...    ...     ...   ...          ...
# 93    DOMINUS 10 years-01/2018    70.0   56.0     1.0  25.0   Foursquare
# 95  BOLOGNE BLACK CANE N°19658    70.0   50.0     1.0  21.0      Bologne
# 96  BOLOGNE BLACK CANE N°19742    70.0   50.0     1.0  21.0      Bologne
# 97      BARBANCOURT VSOP 4 ans    70.0   40.0     1.0  21.0  Barbancourt
# 98            MONTEBELLO 8 ANS    70.0   42.0     1.0  28.0   Montebello
#
# [86 rows x 6 columns]>

# %%
inventaire.shape
# Out:
# (86, 6)

# %%
inventaire.to_excel(r'INVENTAIRE_B.xlsx', index = False, header=True)

# %% [markdown]
# ######

# %% [markdown]
# - nettoyage fichier rhum_data.csv

# %%
csv_file = 'rum_data_brut.csv'
liste_rhum = pd.read_csv(csv_file)

liste_rhum.head(275)
# Out:
#                                   name    company              country  price  \
# 0                   10000 Drops Silver    Unknown        United States      0
# 1                   10000 Drops Spiced    Unknown        United States      0
# 2                      1000 Hills Gold    Unknown               Rwanda      0
# 3            100 Fuegos Buckeye 2-Year    Unknown              Ecuador      0
# 4                    100 Fuegos 8-Year    Unknown              Ecuador      0
# ..                                 ...        ...                  ...    ...
# 270                   Angostura 5-Year  Angostura  Trinidad and Tobago      0
# 271                Antelope Island Red    Unknown        United States      0
# 272  Antelope Island 2017 Single Batch    Unknown        United States      0
# 273                  Antila Dos Azores    Unknown             Portugal      0
# 274     Antillano Antillano Ron AÃ±ejo    Unknown               Mexico      0
#
#      ratings  score      type                                         rum_url  \
# 0          0    0.0     Light                /brands/10972-10000-drops-silver
# 1          1    4.0    Spiced                 /brands/7354-10000-drops-spiced
# 2          1    4.0     Light                    /brands/5285-1000-hills-gold
# 3          0    0.0      Gold          /brands/9037-100-fuegos-buckeye-2-year
# 4          0    0.0      Aged                  /brands/1834-100-fuegos-8-year
# ..       ...    ...       ...                                             ...
# 270       47    6.1      Gold                   /brands/1510-angostura-5-year
# 271        0    0.0      Gold                /brands/9099-antelope-island-red
# 272        1    7.0  Agricole  /brands/8937-antelope-island-2017-single-batch
# 273        1    6.0     Light                  /brands/6645-antila-dos-azores
# 274        1    2.0      Aged      /brands/6435-antillano-antillano-ron-anejo
#
#                                                img_url  br_score
# 0    https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363
# 1    https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  4.711955
# 2    https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  4.711955
# 3    https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363
# 4    https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363
# ..                                                 ...       ...
# 270  https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  5.844571
# 271  https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363
# 272  https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  4.957292
# 273  https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  4.875513
# 274  https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.548397
#
# [275 rows x 10 columns]

# %%
list_unknown = liste_rhum['company'] == 'Unknown'

# %%
filtered_df = liste_rhum[list_unknown]
print(filtered_df.head())
# Out:
#                         name  company        country  price  ratings  score  \
# 0         10000 Drops Silver  Unknown  United States      0        0    0.0
# 1         10000 Drops Spiced  Unknown  United States      0        1    4.0
# 2            1000 Hills Gold  Unknown         Rwanda      0        1    4.0
# 3  100 Fuegos Buckeye 2-Year  Unknown        Ecuador      0        0    0.0
# 4          100 Fuegos 8-Year  Unknown        Ecuador      0        0    0.0
#
#      type                                 rum_url  \
# 0   Light        /brands/10972-10000-drops-silver
# 1  Spiced         /brands/7354-10000-drops-spiced
# 2   Light            /brands/5285-1000-hills-gold
# 3    Gold  /brands/9037-100-fuegos-buckeye-2-year
# 4    Aged          /brands/1834-100-fuegos-8-year
#
#                                              img_url  br_score
# 0  https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363
# 1  https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  4.711955
# 2  https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  4.711955
# 3  https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363
# 4  https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363

# %%
for x in liste_rhum.itertuples():
    print(x.company) # Imprime la valeur courante de la colonne A de df
# Out:
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# 10 Cane
# 10 Cane
# 10 Cane
# 1423
# 1423
# 1423
# 1492
# 1492
# 1492
# 1492
# 1492
# 1492
# 1492
# 1492
# 1492
# 1492
# 1492
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# 1767
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# 1931
# 1931
# 1931
# 1931
# 1931
# 1931
# Unknown
# Unknown
# 3 Horse
# 3 Howls
# 3 Howls
# 3 Howls
# 3 Howls
# 3 Howls
# 3 Zero
# 3 Zero
# Unknown
# Unknown
# Unknown
# Unknown
# 4 Spirits
# Unknown
# Unknown
# Unknown
# 51
# 51
# 51
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# 896
# 896
# 8 PM Bermuda
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# A 1710
# A 1710
# A 1710
# A 1710
# A 1710
# A 1710
# A 1710
# A 1710
# A 1710
# Abelha
# Abelha
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Nelson's
# Admiral Rodney
# Admiral Rodney
# Admiral Rodney
# Admiral Rodney
# Admiral Rodney
# Admiral Rodney
# A. D. Rattray
# A. D. Rattray
# A. D. Rattray
# A. D. Rattray
# Unknown
# Afrohead
# Afrohead
# Agua Luca
# Unknown
# Aguardiente
# Aguardiente
# Aguardiente
# Aguardiente
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# A. H. Riise
# Unknown
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Alambic Classique Collection
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Aldabo
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Alleyne Arthur's
# All Gold
# All Gold
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Alnwick
# Alnwick
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Amrut
# Amrut
# Amrut
# Unknown
# Unknown
# Ancient Mariner
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Angostura
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Antioqueno
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Appleton Estate
# Arcane
# Arcane
# Arcane
# Arcane
# Unknown
# Arecha
# Arecha
# Arecha
# Arecha
# Arecha
# Arecha
# Arecha
# Arecha
# Arehucas
# Arehucas
# Arehucas
# Arehucas
# Arehucas
# Arehucas
# Arehucas
# Arehucas
# Arehucas
# Arehucas
# Arehucas
# Arehucas
# Arehucas
# Arguardente Tiquara
# Armazem Vieira
# Armut
# Arnisser
# Arnisser
# Arnisser
# Arnisser
# Arnisser
# Arnisser
# Arnisser
# Arnisser
# Unknown
# Artemi
# Artemi
# Artemi
# Artemi
# Artemi
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Arundel
# Arundel
# Asmussen
# Asmussen
# Asmussen
# Asmussen
# Asmussen
# Unknown
# Unknown
# Unknown
# Unknown
# Atlantico
# Atlantico
# Atlantico
# Atlantico
# Atocha Gold
# Atocha Gold
# Unknown
# Unknown
# Austrian Empire
# Austrian Empire
# Austrian Empire
# Austrian Empire
# Austrian Empire
# Austrian Empire
# Austrian Empire
# Austrian Empire
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Avua
# Avua
# Avua
# Avua
# Avua
# Avua
# Avua
# Unknown
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Bacardi
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Bajan Estate
# Balcones
# Balcones
# Balcones
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Bambarra
# Bambarra
# Bambarra
# Bambarra
# Bambarra
# Unknown
# Unknown
# Bandarra
# Unknown
# Unknown
# Unknown
# Banks
# Banks
# Banks
# Banks
# Banks
# Banks
# Banks
# Banks
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Baquba
# Baquba
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
#
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Tommy Bahama
# Tommy Bahama
# Tondena
# Tondena
# Tondena
# Tondena
# Tondena
# Topper's
# Topper's
# Topper's
# Topper's
# Topper's
# Topper's
# Unknown
# Tortuga
# Tortuga
# Tortuga
# Tortuga
# Tortuga
# Tortuga
# Tortuga
# Tortuga
# Tortuga
# Tortuga
# Tortuga
# Tortuga
# Tortuga
# Toucan
# Toucan
# Toucan
# Toucan
# Toz
# Toz
# Unknown
# Trader Joe's
# Trader Joe's
# Trader Vics
# Trader Vics
# Trader Vics
# Trader Vics
# Trader Vics
# Trader Vics
# Trader Vics
# Trader Vics
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Travellers
# Travellers
# Travellers
# Travellers
# Travellers
# Travellers
# Travellers
# Unknown
# Treasure Island
# Treaty Oak
# Treaty Oak
# Tremols
# Tremols
# Tremols
# Tremols
# Tremols
# Tres Esquinas
# Tres Esquinas
# Tres Esquinas
# Tres Esquinas
# Tres Esquinas
# Tres Esquinas
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Tres Hombres
# Unknown
# Unknown
# Tricoche
# Trigo
# Unknown
# Unknown
# Unknown
# Unknown
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Trois Rivieres
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Turoa
# Unknown
# Unknown
# Tuthilltown Spirits
# Unknown
# Unknown
# Twenty Boat
# Twenty Boat
# Twenty Boat
# Twenty Boat
# Twenty Boat
# Twenty Boat
# Twezo
# Twezo
# Twezo
# Twezo
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# UF30E
# Ugly Dog
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# UNHIQ
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Velho Barreiro
# Velho Barreiro
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Velier
# Venado
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Very Old Demerara
# Victoria
# Unknown
# Unknown
# Unknown
# Unknown
# Vigia
# Vigia
# Vigia
# Vigia
# Vigia
# Vigia
# Villa Rica
# Villa Rica
# Villa Rica
# Unknown
# Unknown
# Unknown
# Unknown
# Virgin Gorda
# Virgin Gorda
# Virins
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Vizcaya
# Vizcaya
# Vizcaya
# Vizcaya
# Volbeat
# Volbeat
# Unknown
# VooDoo
# Vybz
# Vybz
# Unknown
# Waiwera
# Waiwera
# Unknown
# Unknown
# Watson's
# Watson's
# Unknown
# Unknown
# Unknown
# Unknown
# Weiron
# Weiron
# Unknown
# Unknown
# Westerhall
# Westerhall
# Westerhall
# Westerhall
# Westerhall
# Westerhall
# Westerhall
# Westerhall
# Westerhall
# Westerhall
# Westerhall
# Westerhall
# West Rock
# Unknown
# Whaler's
# Whaler's
# Whaler's
# Whaler's
# Whaler's
# Whaler's
# Whaler's
# Whaler's
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Whisky Broker
# Whisky Broker
# Whisky Broker
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Whistling Andy's
# Whistling Andy's
# White Hat
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Wicked Dolphin
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Wild Tiger
# Wild Tiger
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Witherspoon's
# Witherspoon's
# Wood's 100
# World's End
# World's End
# World's End
# World's End
# World's End
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Wray & Nephew
# Wray & Nephew
# Unknown
# Unknown
# Unknown
# Unknown
# XM
# XM
# XM
# XM
# XM
# XM
# XM
# XM
# XM
# XM
# Unknown
# Xtabentun
# Xtabentun
# Xtabentun
# Xtabentun
# Unknown
# Yacuro
# Yacuro
# Unknown
# Unknown
# Unknown
# Yahara Bay
# Yahara Bay
# Unknown
# Yolo
# Yolo
# Ypioca
# Ypioca
# Ypioca

# %%
# on change les valeurs inconnus par le nom de la bouteille
liste_rhum.loc[liste_rhum['company'] == 'Unknown', 'company'] = liste_rhum['name']

# %%
liste_rhum.to_csv('rum_data_new2.csv', index = False, header=True)

# %% [markdown]
# - remplacement des caractères spéciaux

# %%
csv_file = 'rum_data_new2.csv'
liste_rhum = pd.read_csv(csv_file)

liste_rhum.head(275)
# Out:
#                                   name                            company  \
# 0                   10000 Drops Silver                 10000 Drops Silver
# 1                   10000 Drops Spiced                 10000 Drops Spiced
# 2                      1000 Hills Gold                    1000 Hills Gold
# 3            100 Fuegos Buckeye 2-Year          100 Fuegos Buckeye 2-Year
# 4                    100 Fuegos 8-Year                  100 Fuegos 8-Year
# ..                                 ...                                ...
# 270                   Angostura 5-Year                          Angostura
# 271                Antelope Island Red                Antelope Island Red
# 272  Antelope Island 2017 Single Batch  Antelope Island 2017 Single Batch
# 273                  Antila Dos Azores                  Antila Dos Azores
# 274     Antillano Antillano Ron AÃ±ejo     Antillano Antillano Ron AÃ±ejo
#
#                  country  price  ratings  score      type  \
# 0          United States      0        0    0.0     Light
# 1          United States      0        1    4.0    Spiced
# 2                 Rwanda      0        1    4.0     Light
# 3                Ecuador      0        0    0.0      Gold
# 4                Ecuador      0        0    0.0      Aged
# ..                   ...    ...      ...    ...       ...
# 270  Trinidad and Tobago      0       47    6.1      Gold
# 271        United States      0        0    0.0      Gold
# 272        United States      0        1    7.0  Agricole
# 273             Portugal      0        1    6.0     Light
# 274               Mexico      0        1    2.0      Aged
#
#                                             rum_url  \
# 0                  /brands/10972-10000-drops-silver
# 1                   /brands/7354-10000-drops-spiced
# 2                      /brands/5285-1000-hills-gold
# 3            /brands/9037-100-fuegos-buckeye-2-year
# 4                    /brands/1834-100-fuegos-8-year
# ..                                              ...
# 270                   /brands/1510-angostura-5-year
# 271                /brands/9099-antelope-island-red
# 272  /brands/8937-antelope-island-2017-single-batch
# 273                  /brands/6645-antila-dos-azores
# 274      /brands/6435-antillano-antillano-ron-anejo
#
#                                                img_url  br_score
# 0    https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363
# 1    https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  4.711955
# 2    https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  4.711955
# 3    https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363
# 4    https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363
# ..                                                 ...       ...
# 270  https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  5.844571
# 271  https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.775363
# 272  https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  4.957292
# 273  https://d19vk5i0q1xlsm.cloudfront.net/uploads/...  4.875513
# 274  https://d1jtwiy8m5zi8a.cloudfront.net/assets/d...  4.548397
#
# [275 rows x 10 columns]

# %%
# df.replace([old_value], new_value)
# création liste caractère spéciaux et leurs valeurs de remplacement
dico = {}
liste_car = ['Ã¡', 'Ã»', 'Ã¢', 'Ã©', 'â€™', 'Â°', 'Ã¨', 'Ã³', 'Ã±', '\'']
liste_remp = ['a', 'u', 'a', 'e', '\'', '°', 'e', 'o', 'n', '']
# création du dictionnaire avec une compréhension de dictionnaire
dico = {k: v for k, v in zip(liste_car, liste_remp)}

# %%
# il faut que regex=True 
liste_rhum.replace({'name': dico}, regex=True,inplace=True)

# %%
liste_rhum.replace({'company': dico}, regex=True,inplace=True)

# %%
liste_rhum.to_csv('rum_data_new3.csv', index = False, header=True)

# %% [markdown]
# ######

# %% [markdown]
# - Bonus

# %% [markdown]
# --> Nettoyage fichier json avec les expressions régulières

# %%
import json

with open('test.json', 'r') as f:
    data = json.load(f)

print(data[0:5])

# %%
# suppressoin des espaces avant 'cl'
liste_json = []
for rum in data:
    for k, v in rum.items():
        v = v.replace(' cl', 'cl')
        liste_json.append(v)
liste_json[0:10]

# %%
for e in liste_json:
    pays = e.split()[-1]

print(e)
print(pays)
# exporter les données dans un fichier json

# %%
# test expression reguliere pour volume
import re

pattern = re.compile(r'\d\dcl')

matches = pattern.findall('efefe 70cl dzef')

for match in matches:
    print(match)

# %%
# test expression reguliere pour degre
import re

pattern = re.compile(r'(\d+(?:\.\d+)?°)')

matches = pattern.findall('efefe 50° dzef 55.8°')

for match in matches:
    print(match)

# %% [markdown]
# -----------------

# %% [markdown]
# ### Insertion des données

# %% [markdown]
# - origine

# %%
# Prod
# liste des origines pour insertions

import csv
# je crée une liste regroupant ma liste de pays
liste = []
with open('rum_data_new3.csv', newline='', encoding='utf-8') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        # gestion des doublons
        if row[2] not in liste:
            liste.append(row[2])
liste = liste[1:]
print(liste)
# Out:
# ['United States', 'Rwanda', 'Ecuador', 'Trinidad and Tobago', 'Panama', 'Switzerland', 'Netherlands', 'Germany', 'Belgium', 'Saint Lucia', 'Belize', 'India', 'Australia', 'Brazil', 'Barbados', 'Portugal', 'Virgin Islands, U.S.', 'Martinique', 'Mexico', 'United Kingdom', 'Colombia', 'Spain', 'Denmark', 'Caribbean', 'Cuba', 'Dominican Republic', 'Guyana', 'Guatemala', 'Jamaica', 'Mauritius', 'Guadeloupe', 'British Virgin Islands', 'Puerto Rico', 'Croatia', 'Bahamas', 'Sri Lanka', 'Finland', 'Turks and Caicos Islands', 'Antigua and Barbuda', 'RÃ©union', 'Lithuania', 'Haiti', 'Sweden', 'Grenada', 'Venezuela', 'Fiji', 'Dominica', 'Vietnam', 'Saint Kitts And Nevis', 'Bermuda', 'Cayman Islands', 'Suriname', 'New Zealand', 'Thailand', 'Estonia', 'United States Minor Outlying Islands', 'Italy', 'France', 'Czech Republic', 'Indonesia', 'Peru', 'Canada', 'Costa Rica', 'USA', 'Nicaragua', 'Bulgaria', 'Romania', 'Venezuela, Bolivarian Republic of', 'Hungary', 'Reunion', 'El Salvador', 'Trinidad', 'Greece', 'Philippines', 'South Africa', 'CuraÃ§ao', 'Madagascar', 'Uruguay', 'Austria', 'Taiwan, Republic Of China', 'Paraguay', 'Cambodia', 'Slovakia', 'French Polynesia', 'Japan', 'Argentina', 'Saint Martin', 'Kenya', 'Nepal', 'Malta', 'Seychelles', 'Myanmar', 'United Arab Emirates', 'Aruba', 'Honduras', 'Mexique', 'Poland', 'Anguilla', 'Bonaire, Sint Eustatius and Saba', 'Saint BarthÃ©lemy', 'Andorra', 'Netherlands Antilles', 'Jamaica & Guyana ', 'Sint Maarten', 'Saint Vincent And The Grenedines', 'Liechtenstein', 'British West Indies', 'Cape Verde', 'Brasil', 'Ireland']

# %%
# connexion à la bdd collection
conn = psycopg2.connect(
        user = "postgres",
        password = os.environ.get("pg_psw"),
        host = "localhost",
        port = "5432",
        database = "collection3"
)
cur = conn.cursor()

for pays in liste:
    cur.execute("SELECT origine.nom FROM origine WHERE origine.nom = (%s) ", (pays,))
    verif = cur.fetchone()
    if not verif:
        cur.execute("INSERT INTO origine (nom) VALUES(%s)", (pays,))

conn.commit()
conn.close()

# %% [markdown]
# ######

# %% [markdown]
# - insertion producteur

# %%
# prod
# je crée une liste regroupant les pays et les producteurs
liste_co = []
with open('rum_data_new3.csv', newline='', encoding='utf-8') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        if row[1:3] not in liste_co:
            liste_co.append((row[1:3]))
liste_co = liste_co[1:]
print(liste_co[0:10])
# Out:
# [['10000 Drops Silver', 'United States'], ['10000 Drops Spiced', 'United States'], ['1000 Hills Gold', 'Rwanda'], ['100 Fuegos Buckeye 2-Year', 'Ecuador'], ['100 Fuegos 8-Year', 'Ecuador'], ['105 Simonton', 'United States'], ['10 Cane', 'Trinidad and Tobago'], ['1423', 'Panama'], ['1492', 'United States'], ['1653 Old Barrel', 'Switzerland']]

# %%
# prod
# fonction d'insertion dans la table producteur
conn = psycopg2.connect(
        user = "postgres",
        password = os.environ.get("pg_psw"),
        host = "localhost",
        port = "5432",
        database = "collection3"
)
cur = conn.cursor()
for producteur, pays in liste_co:
    #print(producteur)
    #print(pays)
    cur.execute(f"""SELECT origine.code_origine 
        FROM origine
        WHERE origine.nom = '{pays}';
        """)
    
    origine = cur.fetchone()[0]
    #print(origine)
    #pays = str(pro[0])
    #print(pays)

    cur.execute(f"INSERT INTO producteur (nom, code_origine) VALUES ('{producteur}', {origine})")
    
cur.close()
conn.commit()
conn.close()

# %% [markdown]
# ######

# %% [markdown]
# - insertion produit

# %%
# insertion fichier excel
excel_file = 'INVENTAIRE_B.xlsx'
inventaire = pd.read_excel(excel_file)
inventaire.head()
# Out:
#                NOM  VOLUME  DEGRE  NOMBRE  PRIX MARQUE
# 0           C12 70      70   50.0       5   8.5    HSE
# 1           C16 70      70   50.0       1  11.0    HSE
# 2          C16 100     100   50.0       1  14.0    HSE
# 3   PARCELLAIRE 70      70   55.0       2  13.0    HSE
# 4  PARCELLAIRE 100     100   55.0       1  15.0    HSE

# %%
inventaire_produit =  inventaire[['NOM', 'VOLUME', 'DEGRE', 'MARQUE']]

# %%
liste_inventaire = [list(x) for x in inventaire_produit.to_numpy()]
print(liste_inventaire[0:10])
# Out:
# [['C12 70', 70, 50.0, 'HSE'], ['C16 70', 70, 50.0, 'HSE'], ['C16 100', 100, 50.0, 'HSE'], ['PARCELLAIRE 70', 70, 55.0, 'HSE'], ['PARCELLAIRE 100', 100, 55.0, 'HSE'], ['PARCELLAIRE 150L', 150, 55.0, 'HSE'], ['RAGTIME ESB', 70, 40.0, 'HSE'], ['Coffret XO ENO', 70, 43.0, 'HSE'], ['Small Cask 2007-22/10/2015, n°848', 50, 46.0, 'HSE'], ['Small Cask 2007-20/08/2018, n°596', 50, 46.0, 'HSE']]

# %%
nom = liste_inventaire[0][0]
volume = liste_inventaire[0][1]
degre = liste_inventaire[0][2]
marque = liste_inventaire[0][3]

print(nom)
print(volume)
print(degre)
print(marque)
# Out:
# C12 70
# 70
# 50.0
# HSE

# %%
conn = psycopg2.connect(
        user = "postgres",
        password = os.environ.get("pg_psw"),
        host = "localhost",
        port = "5432",
        database = "collection3"
)
cur = conn.cursor()
for nom, volume, degre, marque in liste_inventaire:
    print(marque)
    
    cur.execute(f"""SELECT producteur.code_producteur 
        FROM producteur
        WHERE producteur.nom = '{marque}';
        """)
    
    code = cur.fetchone()[0]
    print(code)
    
    cur.execute(f"INSERT INTO produit (nom, volume, degre, code_producteur) VALUES ('{nom}', {volume}, {degre}, {code})")
print(type(cur))   
cur.close()
conn.commit()
conn.close()
# Out:
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# HSE
# 1476
# Rhum JM
# 2435
# Rhum JM
# 2435
# Rhum JM
# 2435
# Rhum JM
# 2435
# Rhum JM
# 2435
# Rhum JM
# 2435
# Rhum JM
# 2435
# Rhum JM
# 2435
# La Mauny
# 1715
# La Mauny
# 1715
# La Mauny
# 1715
# La Mauny
# 1715
# La Mauny
# 1715
# La Mauny
# 1715
# La Mauny
# 1715
# La Mauny
# 1715
# La Mauny
# 1715
# Depaz
# 1029
# Depaz
# 1029
# Depaz
# 1029
# Depaz
# 1029
# Depaz
# 1029
# J. Bally
# 1558
# J. Bally
# 1558
# J. Bally
# 1558
# Clement
# 818
# Clement
# 818
# Clement
# 818
# Trois Rivieres
# 3043
# Trois Rivieres
# 3043
# Trois Rivieres
# 3043
# Neisson
# 2063
# Neisson
# 2063
# A 1710
# 61
# A 1710
# 61
# A 1710
# 61
# A 1710
# 61
# A 1710
# 61
# Saint James
# 2615
# Saint James
# 2615
# La Mauny
# 1715
# La Mauny
# 1715
# Foursquare
# 1313
# Foursquare
# 1313
# Bologne
# 463
# Bologne
# 463
# Barbancourt
# 246
# Montebello
# 1975
# <class 'psycopg2.extensions.cursor'>

# %%
# insertion fichuer csv
# prod
# je crée une liste regroupant les pays et les producteurs
liste_groupe = []
with open('rum_data_new3.csv', newline='', encoding='utf-8') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        liste_groupe.append((row[0:2]))
liste_groupe = liste_groupe[1:]
print(liste_groupe[0:10])
# Out:
# [['10000 Drops Silver', '10000 Drops Silver'], ['10000 Drops Spiced', '10000 Drops Spiced'], ['1000 Hills Gold', '1000 Hills Gold'], ['100 Fuegos Buckeye 2-Year', '100 Fuegos Buckeye 2-Year'], ['100 Fuegos 8-Year', '100 Fuegos 8-Year'], ['105 Simonton', '105 Simonton'], ['10 Cane 1999 Guyana 15-Year', '10 Cane'], ['10 Cane Light', '10 Cane'], ['10 Cane Signature Blend', '10 Cane'], ['1423 Indian Rum', '1423']]

# %%
conn = psycopg2.connect(
        user = "postgres",
        password = os.environ.get("pg_psw"),
        host = "localhost",
        port = "5432",
        database = "collection3"
)
cur = conn.cursor()
for nom, marque in liste_groupe:
    #print(producteur)
    #print(pays)
    cur.execute(f"""SELECT producteur.code_producteur 
        FROM producteur
        WHERE producteur.nom = '{marque}';
        """)
    code = cur.fetchone()[0]
    
    cur.execute(f"INSERT INTO produit (nom, code_producteur) VALUES ('{nom}', {code})")
print(type(cur))   
cur.close()
conn.commit()
conn.close()
# Out:
# <class 'psycopg2.extensions.cursor'>
