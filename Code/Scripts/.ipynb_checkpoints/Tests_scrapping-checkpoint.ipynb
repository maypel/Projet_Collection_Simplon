# %%
import pandas as pd
url = "https://wikirum.fr/brand/info/391"
tables = pd.read_html(url) 
tables[]

# %%
# import libraries
from bs4 import BeautifulSoup
import urllib.request
import csv

# %%
# specify the url
urlpage = 'https://wikirum.fr/brand/info/391'

# %%
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup)

# %%
urlpage2 = 'https://rumratings.com/brands?utf8=%E2%9C%93&search=hse'

# %%
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage2)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup)

# %%
urlpage3 = 'https://www.lacompagniedurhum.com/catalogsearch/result/?form_key=4pKSk25SS8y18tig&q=hse'

# %%
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage3)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup)

# %%
urlpage4 = 'https://www.lacompagniedurhum.com/catalogsearch/result/?form_key=4pKSk25SS8y18tig&q=depaz&origine=5764'

# %%
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage4)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup)

# %%
urlpage5 = 'https://wikirum.fr/rums'

# %%
# query the website and return the html to the variable 'page'
page = urllib.request.urlopen(urlpage5)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="index, follow" name="robots"/>
# <meta content="WikiRum" name="title"/>
# <meta content="WikiRum" property="og:title"/>
# <meta content="assets/icons/main_logo.png" property="og:image"/>
# <meta content="Trouver des informations sur un rhum n'a jamais été aussi simple" property="og:description"/>
# <meta content="Trouver des informations sur un rhum n'a jamais été aussi simple" name="description"/>
# <title>WikiRum</title>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0,user-scalable=0" name="viewport"/>
# <link href="assets/icons/main_logo.png" rel="icon" type="image/x-icon"/>
# <style type="text/css">@font-face{font-family:'Titillium Web';font-style:normal;font-weight:400;src:url(https://fonts.gstatic.com/s/titilliumweb/v9/NaPecZTIAOhVxoMyOr9n_E7fdMPmCw.woff) format('woff');}@font-face{font-family:'Titillium Web';font-style:normal;font-weight:400;src:url(https://fonts.gstatic.com/s/titilliumweb/v9/NaPecZTIAOhVxoMyOr9n_E7fdM3mDaZRbryhsA.woff2) format('woff2');unicode-range:U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;}@font-face{font-family:'Titillium Web';font-style:normal;font-weight:400;src:url(https://fonts.gstatic.com/s/titilliumweb/v9/NaPecZTIAOhVxoMyOr9n_E7fdMPmDaZRbrw.woff2) format('woff2');unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;}</style>
# <style type="text/css">@font-face{font-family:'Material Icons';font-style:normal;font-weight:400;src:url(https://fonts.gstatic.com/s/materialicons/v77/flUhRq6tzZclQEJ-Vdg-IuiaDsNa.woff) format('woff');}.material-icons{font-family:'Material Icons';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;font-feature-settings:'liga';}@font-face{font-family:'Material Icons';font-style:normal;font-weight:400;src:url(https://fonts.gstatic.com/s/materialicons/v77/flUhRq6tzZclQEJ-Vdg-IuiaDsNcIhQ8tQ.woff2) format('woff2');}.material-icons{font-family:'Material Icons';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;-webkit-font-feature-settings:'liga';-webkit-font-smoothing:antialiased;}</style>
# <link href="manifest.webmanifest" rel="manifest"/>
# <meta content="#1976d2" name="theme-color"/>
# <style type="text/css">@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmSU5fBBc-.woff) format('woff');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu4mxM.woff) format('woff');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmEU9fBBc-.woff) format('woff');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmSU5fCRc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmSU5fABc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmSU5fCBc4AMP6lbBP.woff2) format('woff2');unicode-range:U+1F00-1FFF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmSU5fBxc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0370-03FF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmSU5fCxc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+1EA0-1EF9, U+20AB;}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmSU5fChc4AMP6lbBP.woff2) format('woff2');unicode-range:U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOlCnqEu92Fr1MmSU5fBBc4AMP6lQ.woff2) format('woff2');unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu72xKKTU1Kvnz.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu5mxKKTU1Kvnz.woff2) format('woff2');unicode-range:U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu7mxKKTU1Kvnz.woff2) format('woff2');unicode-range:U+1F00-1FFF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu4WxKKTU1Kvnz.woff2) format('woff2');unicode-range:U+0370-03FF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu7WxKKTU1Kvnz.woff2) format('woff2');unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+1EA0-1EF9, U+20AB;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v20/KFOmCnqEu92Fr1Mu7GxKKTU1Kvnz.woff2) format('woff2');unicode-range:U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;}@font-face ...
# <link href="styles.c89ad8fee64c4930a2c1.css" rel="stylesheet"/></head>
# <body class="igx-typography">
# <app-root></app-root>
# <noscript>Please enable JavaScript to continue using this application.</noscript>
# <script src="runtime-es2015.a4dadbc03350107420a4.js" type="module"></script><script defer="" nomodule="" src="runtime-es5.a4dadbc03350107420a4.js"></script><script defer="" nomodule="" src="polyfills-es5.3864aae88b62af31c21d.js"></script><script src="polyfills-es2015.fc112b12e348a29e974a.js" type="module"></script><script defer="" src="scripts.4b541c6e0bfa2ae5c545.js"></script><script src="main-es2015.edbd1f217148251085df.js" type="module"></script><script defer="" nomodule="" src="main-es5.edbd1f217148251085df.js"></script></body>
# </html>

# %%
url = 'https://rumratings.com/brands?utf8=%E2%9C%93&search=hse'

# %%
from bs4 import BeautifulSoup
import requests


url_rum = requests.get(url)

soup = BeautifulSoup(url_rum.text, 'lxml')

#for item in soupe.findAll('a', {'class' : 'ent-name'})[:10]:   
print(soup)
# Out:
# <html><body><p>Full Name,Country,My Rating,Average Rating,Best Price
# HSE 2007 Blanc Cuvée de l'an,Martinique,,7.55,
# HSE VSOP,Martinique,,7.05,
# HSE Blanc,Martinique,,6.66,
# HSE VO,Martinique,,7.46,
# HSE Eleve sous bois,Martinique,,6.5,
# HSE XO,Martinique,,7.84,90.66
# HSE 2000 Blanc Cuvée de l'an,Martinique,,8.67,
# HSE Sherry Finish,Martinique,,8.2,
# HSE Single Cask,Martinique,,9.0,
# HSE Single Malt Finish,Martinique,,7.5,
# HSE 1960,Martinique,,0.0,
# HSE La Belle Heure,Martinique,,7.67,
# HSE Black Sheriff,Martinique,,6.59,
# HSE Porto Finish,Martinique,,7.5,
# HSE 2003 Single Cask,Martinique,,8.75,
# HSE 2004 Small Cask,Martinique,,8.67,
# HSE Cuvee Titouan Lamazou,Martinique,,7.5,
# HSE 2005 Sherry Pedro Ximenez Finish,Martinique,,7.0,
# HSE 2003 Sauternes Finish,Martinique,,7.17,
# HSE 2004 Sherry Fino &amp; Oloroso Finish,Martinique,,6.2,
# HSE 2005 Single Malt Islay Finish,Martinique,,7.75,
# HSE 2005 Single Malt Highland Finish,Martinique,,7.57,
# HSE Blanc 55,Martinique,,6.75,
# HSE 2003 4-Year,Martinique,,7.0,
# </p></body></html>

# %%
url = 'https://rumratings.com/brands?utf8=%E2%9C%93&page=1&search=depaz'

# %%
from bs4 import BeautifulSoup
import requests


url_rum = requests.get(url)

soup = BeautifulSoup(url_rum.text, 'lxml')

#for item in soupe.findAll('a', {'class' : 'ent-name'})[:10]:   
print(soup)
# Out:
# <html><body><p>Full Name,Country,My Rating,Average Rating,Best Price
# Depaz Blanc,Martinique,,6.11,21.57
# Depaz Blue Cane Amber,Martinique,,6.4,
# Depaz Grande Reserve XO White Label 12-Year,Martinique,,8.27,81.42
# Depaz Paille Agricole,Martinique,,0.0,
# Depaz VSOP,Martinique,,7.31,56.34
# Depaz Cuvee du Grand Saint Pierre XO,Martinique,,8.0,
# Depaz Cuvée de la Montagne Pelée,Martinique,,6.83,
# Depaz Cuvee Prestige,Martinique,,8.56,119.97
# Depaz Vieux,Martinique,,5.29,
# Depaz Plantation,Martinique,,7.0,39.68
# Depaz 2002 Hors d'Age,Martinique,,7.88,
# Depaz 2003 Single Cask,Martinique,,7.5,
# Depaz Eleve Sous Bois,Martinique,,4.0,
# Depaz Blanc 55,Martinique,,5.5,
# Depaz Blanc 50,Martinique,,3.0,
# Depaz 2003 Brut de Fût,Martinique,,6.5,
# Depaz Port Cask Finish,Martinique,,5.75,
# Depaz Rhum Doré Agricole,Martinique,,3.0,
# Depaz Grande Reserve XO Blue Label 8-Year,Martinique,,8.0,
# </p></body></html>

# %%
url = 'https://rumratings.com/brands?page=2&search=hse'

# %%
from bs4 import BeautifulSoup
import requests


url_rum = requests.get(url)

soup = BeautifulSoup(url_rum.text, 'lxml')

#for item in soupe.findAll('a', {'class' : 'ent-name'})[:10]:   
print(soup)
# Out:
# <html><body><p>Full Name,Country,My Rating,Average Rating,Best Price
# HSE 2007 La Confrerie du,Martinique,,6.5,
# HSE 2005 Sauternes Finish Château de la Tour Blanche,Martinique,,6.8,
# HSE Saint Etienne Blanc 40,Martinique,,5.8,31.65
# HSE Ragtime,Martinique,,6.0,
# HSE 2012 Cuvée De L''an,Martinique,,6.0,
# HSE 2003 Single Cognac Cask,Martinique,,8.0,
# HSE 2007 Sherry Fino &amp; Oloroso Cask Finish,Martinique,,4.0,
# HSE 2009 Port Cask Finish,Martinique,,6.67,
# HSE 2007,Martinique,,6.0,
# HSE 2007 Brut de Fût,Martinique,,7.5,
# HSE Vieilli en Fûts de Chêne,Martinique,,5.5,
# HSE 2016 Parcellaire # 1 Canne d'Or,Martinique,,4.0,
# HSE 2003 XO,Martinique,,6.0,
# HSE Le Voyage des Imaginaires Federica Matta,Martinique,,5.5,
# HSE 2006 Finition Marquis de Terme,Martinique,,7.0,
# HSE 2010 Cuvée de L’an,Martinique,,8.0,
# HSE Vsop Port Cask Finish 4-Year,Martinique,,0.0,
# </p></body></html>

# %%
url = 'https://rumratings.com/brands?utf8=%E2%9C%93&page=2&search=longueteau'

# %%
from bs4 import BeautifulSoup
import requests


url_rum = requests.get(url)

soup = BeautifulSoup(url_rum.text, 'lxml')

#for item in soupe.findAll('a', {'class' : 'ent-name'})[:10]:   
print(soup)
# Out:
# <html><body><p>Full Name,Country,My Rating,Average Rating,Best Price
# Longueteau Punch Abricot Pays,Guadeloupe,,3.0,
# Longueteau Symphonie,Guadeloupe,,6.0,
# Longueteau PrÃ©lude,Guadeloupe,,4.5,
# Longueteau Concerto,Guadeloupe,,6.0,
# Longueteau Single Cask,Guadeloupe,,5.0,
# Longueteau Punch Citron Vert,Guadeloupe,,4.0,
# Longueteau Punch Planteur,Guadeloupe,,4.0,
# Longueteau Punch Coco,Guadeloupe,,4.0,
# Longueteau Creole Spicy,Guadeloupe,,4.0,
# Longueteau Premium Shrubb,Guadeloupe,,6.0,
# Longueteau 3-Year,Guadeloupe,,4.0,
# </p></body></html>

# %%
url = 'https://rumratings.com/brands?utf8=%E2%9C%93&page=2&search=montebello'

# %%
from bs4 import BeautifulSoup
import requests


url_rum = requests.get(url)

soup = BeautifulSoup(url_rum.text, 'lxml')

#for item in soupe.findAll('a', {'class' : 'ent-name'})[:10]:   
print(soup)
# Out:
# <html><body><p>Full Name,Country,My Rating,Average Rating,Best Price
# Montebello 2002 Cuvée Heritage 15-Year,Guadeloupe,,0.0,
# Montebello Rare 1948 42-Year,Guadeloupe,,0.0,
# Montebello 2013 Cuvée Special 40%,Guadeloupe,,0.0,
# </p></body></html>

# %%
url = 'https://rumratings.com/brands?utf8=%E2%9C%93&page=2&search=longueteau'

# %%
from bs4 import BeautifulSoup
import requests


url_rum = requests.get(url)

soup = BeautifulSoup(url_rum.text, 'html5lib')

#for item in soupe.findAll('a', {'class' : 'ent-name'})[:10]:   
print(soup)
# Out:
# <html><head></head><body>Full Name,Country,My Rating,Average Rating,Best Price
# Longueteau Punch Abricot Pays,Guadeloupe,,3.0,
# Longueteau Symphonie,Guadeloupe,,6.0,
# Longueteau PrÃ©lude,Guadeloupe,,4.5,
# Longueteau Concerto,Guadeloupe,,6.0,
# Longueteau Single Cask,Guadeloupe,,5.0,
# Longueteau Punch Citron Vert,Guadeloupe,,4.0,
# Longueteau Punch Planteur,Guadeloupe,,4.0,
# Longueteau Punch Coco,Guadeloupe,,4.0,
# Longueteau Creole Spicy,Guadeloupe,,4.0,
# Longueteau Premium Shrubb,Guadeloupe,,6.0,
# Longueteau 3-Year,Guadeloupe,,4.0,
# </body></html>

# %%
url = 'https://www.excellencerhum.com/fr/43-martinique'

# %%
from bs4 import BeautifulSoup
import requests


url_rum = requests.get(url)

soup = BeautifulSoup(url_rum.text, 'lxml')

#for item in soupe.findAll('a', {'class' : 'ent-name'})[:10]:   
print(soup)
# Out:
# <html><body><h1>403 Forbidden</h1>
# Request forbidden by administrative rules.
# </body></html>

# %%
# Récupération des infos sur un pokemon https://pokemondb.net/pokedex/bulbasaur
import urllib
import bs4
from urllib.request import Request, urlopen

# Etape 1 : se connecter à la page et obtenir le code source
# utilisation de l'objet requête avec en-tête pour éviter une erreur "HTTP Error 403: Forbidden"

url_pokemon = "https://www.excellencerhum.com/fr/43-martinique"

req = Request(url_pokemon, headers={'User-Agent': 'Mozilla/5.0'})
html = urlopen(req).read().decode('utf-8')
print(html)
# Out:
#
#
# 	<!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7 lt-ie6 " lang="fr"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8 ie7" lang="fr"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9 ie8" lang="fr"> <![endif]-->
# <!--[if gt IE 8]> <html lang="fr" class="no-js ie9" lang="fr"> <![endif]-->
# <html xmlns="http://www.w3.org/1999/xhtml" version="XHTML+RDFa 1.0" lang="fr" xml:lang="fr">
# 	<head>
# 		<title>Rhum Agricole de Martinique</title>
# 		<meta name="description" content="Achetez tous les rhums de Martinique, des rhums d&#039;exceptions, AOC Martinique, Rhum blanc, vieux, millésimés, mono variétal" />
# 		<meta http-equiv="Content-Type" content="application/xhtml+xml; charset=utf-8" />
# 		<meta http-equiv="content-language" content="en-fr-it-de-es" />
# 		<meta name="robots" content="index,follow" />
# 		<meta name="verify-a" value="1a73286679d5564e6d3b">
# 		<meta name="msvalidate.01" content="6C359A98713B4E7E2F78358877702281" />
# 		<meta name="google-site-verification" content="aW7VREn6lvv-GUwwJfc0-eH4mphDuaNauFrO79lteLQ" />
# 		<link rel="canonical" href="https://www.excellencerhum.com/fr/43-martinique"/>
#
# 		<link rel="alternate" hreflang="en-us" href="https://www.excellencerhum.com/en/43-martinique" />
#
# 		<link rel="alternate" hreflang="fr" href="https://www.excellencerhum.com/fr/43-martinique" />
#
# 		<link rel="alternate" hreflang="it-it" href="https://www.excellencerhum.com/it/43-martinique" />
#
# 		<link rel="alternate" hreflang="de-de" href="https://www.excellencerhum.com/de/43-martinique" />
#
# 		<link rel="alternate" hreflang="es-es" href="https://www.excellencerhum.com/es/43-martinique" />
# 		<link rel="dns-prefetch" href="https://cdn1.excellencerhum.com">
# 		<link rel="dns-prefetch" href="https://cdn2.excellencerhum.com">
# 		<link rel="dns-prefetch" href="https://cdn3.excellencerhum.com">
#         <link rel="shortcut icon" href="https://cdn1.excellencerhum.com/img/favicon/favicon.png">
#         <link rel="apple-touch-icon" sizes="144x144" href="https://cdn1.excellencerhum.com/img/favicon/favicon-retina-ipad.png">
#         <link rel="apple-touch-icon" sizes="114x114" href="https://cdn1.excellencerhum.com/img/favicon/favicon-retina-iphone.png">
#         <link rel="apple-touch-icon" sizes="72x72" href="https://cdn1.excellencerhum.com/img/favicon/favicon-standard-ipad.png">
#         <link rel="apple-touch-icon" sizes="57x57" href="https://cdn1.excellencerhum.com/img/favicon/favicon-standard-iphone.png">
# 		<!-- OLD
# 		<link rel="icon" type="image/vnd.microsoft.icon" href="/img/favicon.ico?1605466797" />
# 		<link rel="shortcut icon" type="image/x-icon" href="/img/favicon.ico?1605466797" />
# 		OLD -->
# 		<link rel="author" href="https://plus.google.com/+ExcellencerhumOfficiel" />
# 		<meta property="og:type" content="product" />
# 		<meta property="og:site_name" content="ExcellenceRhum" />
# 		<meta property="og:url" content="https://www.excellencerhum.com/fr/43-martinique" />
# 		<meta property="og:title" content="Rhum Agricole de Martinique" />
# 		<meta property="og:description" content="Achetez tous les rhums de Martinique, des rhums d&#039;exceptions, AOC Martinique, Rhum blanc, vieux, mill&eacute;sim&eacute;s, mono vari&eacute;tal" />
#
# 		<meta property="og:image" content="" />
# 		<meta property="og:image:secure_url" content="" />
# 		<meta property="og:image:width" content="900" />
# 		<meta property="og:image:height" content="900" />
#
# 		<meta property="og:locale" content="fr_FR" />
#
# 		<script type="text/javascript">
# 			var baseDir = 'https://www.excellencerhum.com/';
# 			var baseUri = 'https://www.excellencerhum.com/';
# 			var static_token = '6bc999f3565e7416514b9cf9a726bdec';
# 			var token = '9ba92740405991532c1457100b225c0c';
# 			var priceDisplayPrecision = 2;
# 			var priceDisplayMethod = 0;
# 			var roundMode = 2;
# 		</script>
# 		<script type="application/ld+json">
# 		{
# 		  "@context": "http://schema.org",
# 		  "@type": "Organization",
# 		  "url": "https://www.excellencerhum.com",
# 		  "logo": "https://cdn1.excellencerhum.com/img/logo-1.jpg"
# 		}
# 		</script>
# 		<script type="application/ld+json">
# 		{
# 		"@context" : "http://schema.org",
# 		"@type" : "WebSite",
# 		"name" : "ExcellenceRhum",
# 		"url" : "https://www.excellencerhum.com"
# 		}
# 		</script>
#
# 		<link href="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/fonts/font-awesome/css/font-awesome.min.css" rel="stylesheet">
# 		<!-- Only for xmas, fatherday...
# 		<link href="https://fonts.googleapis.com/css?family=Pinyon+Script" rel="stylesheet">
# 		-->
# 		<link href="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/fonts/mapglyphs/mapglyphs.css" rel="stylesheet">
#
# 	<!--[if IE 7]><link href="https://cdn2.excellencerhum.com/themes/ExcellenceRhum/css/global-ie.css" rel="stylesheet" type="text/css" media="0" /><![endif]-->
# 			<link href="https://cdn3.excellencerhum.com/themes/ExcellenceRhum/cache/fde039500961b339ca85e3a58266441c_all.css" rel="stylesheet" type="text/css" media="all" />
#
#
# 			<script type="text/javascript" src="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/cache/10647072a12be645f36661a39ebe2957.js"></script>
#
#
# 	<!--[if lt IE 8]>
# 	<script type="text/javascript" src="https://www.excellencerhum.com/modules/pm_advancedtopmenu/js/pm_advancedtopmenuiefix.js"></script>
# 	<![endif]-->
#
# <link rel="alternate" type="application/rss+xml" title="Rhum Agricole de Martinique" href="https://www.excellencerhum.com/modules/feeder/rss.php?id_category=43&amp;orderby=quantity&amp;orderway=desc" /><script type="text/javascript">
# 						var NPRO_AJAX_URL = '/modules/newsletterpro/ajax/ajax_newsletterpro_front.php';
# 					</script>
# <script>
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
# 	ga('create', 'UA-51664203-1', 'www.excellencerhum.com');
# 	ga('send', 'pageview');
# </script><!-- MODULE PM_AdvancedSearch4 || Presta-Module.com -->
# <script type="text/javascript">
# var ASPath = '/modules/pm_advancedsearch4/';
# var ASSearchUrl = 'https://www.excellencerhum.com/fr/module/pm_advancedsearch4/advancedsearch4';
# var ASParams = {};
# var ASHash = {};
# var ASPSVersion = '1.5.6.2';
# $(document).ready(function() { asInitAsHashChange(); });
# </script>
# <!-- MODULE PM_AdvancedSearch4 || Presta-Module.com --><script type="text/javascript">
# 	var modalCartjQuerySelector = '.ajax_add_to_cart_button';
# 	var modalCartProductjQuerySelector = 'body#product p#add_to_cart input, body#product p#add_to_cart button';
# 	var modalCartWidth = '600';
# 	var modalCartType = 'lpa';
# 	var modalCartOverlay = true;
# 	var modalCartOverlayOpacity = '0.45';
# 	var modalCartFreeProductTranslation = 'Gratuit !';
# 	var modalCartDisplayCloseButton = false;
# 	var modalCartOrderPageLink = 'https://www.excellencerhum.com/fr/commande';
# 	var modalCartControllerLink = 'https://www.excellencerhum.com/fr/module/pm_modalcart3/ajax_front';
# </script><script type="text/javascript">
# 	var favorite_products_url_add = 'https://www.excellencerhum.com/fr/module/favoriteproducts/actions?process=add';
# 	var favorite_products_url_remove = 'https://www.excellencerhum.com/fr/module/favoriteproducts/actions?process=remove';
#
# </script>
#
# 			<script type="text/javascript">
# 				(window.gaDevIds=window.gaDevIds||[]).push('d6YPbH');
# 				(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 				(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 				m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 				})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# 				ga('create', 'UA-51664203-1', 'auto');
# 				ga('require', 'ec');
#
# 			</script>
# 	    <script type="text/javascript">
#         var jQuery144 = $;
#     </script>
#
#
#
#
# 	<script type="text/javascript">
# 	    // instantiate object
# 	    var gsr = gsr || new GsrModule('gsr');
#
# 	    // get errors translation
# 		gsr.msgs = {"delay":"Vous n'avez pas rempli un entier l'option d\u00e9calage","fbId":"Vous n'avez pas rempli un entier l'option Facebook app ID","fbsecret":"Vous n'avez pas rempli l'option Facebook secret","title":"Vous n'avez pas rempli le titre","description":"Vous n'avez pas rempli le commentaire","rating":"Vous n'avez pas s\u00e9lectionn\u00e9 de note pour l'avis","checkreview":"Vous n'avez pas s\u00e9lectionn\u00e9 au moins un avis","email":"Vous n'avez pas rempli votre adresse e-mail","vouchercode":"Vous n'avez pas rempli le code de r\u00e9duction","voucheramount":"Vous avez laiss\u00e9 0 comme montant du bon de r\u00e9duction","voucherminimum":"Le montant minimum n'est pas un num\u00e9rique","vouchermaximum":"La quantit\u00e9 maximum n'est pas un num\u00e9rique","vouchervalidity":"Vous avez laiss\u00e9 0 pour la dur\u00e9e de validit\u00e9","tabTitle":{"1":"Vous n'avez pas rempli le titre pour la langue English (English). Cliquer sur le drapeau de langues afin de remplir correctement tous les champs de traduction.","5":"Vous n'avez pas rempli le titre pour la langue Fran\u00e7ais (French). Cliquer sur le drapeau de langues afin de remplir correctement tous les champs de traduction.","6":"Vous n'avez pas rempli le titre pour la langue Italiano (Italian). Cliquer sur le drapeau de langues afin de remplir correctement tous les champs de traduction.","7":"Vous n'avez pas rempli le titre pour la langue Deutsch (German). Cliquer sur le drapeau de langues afin de remplir correctement tous les champs de traduction.","9":"Vous n'avez pas rempli le titre pour la langue Espa\u00f1ol (Spanish). Cliquer sur le drapeau de langues afin de remplir correctement tous les champs de traduction."}};
#
#
# 	    // set URL of admin img
# 		gsr.sImgUrl = '/modules/gsnippetsreviews/img/';
#
# 		            // set URL of module's web service
# 			gsr.sWebService = '/modules/gsnippetsreviews/ws-gsnippetsreviews.php';
# 			</script>
# 	    <script type="text/javascript" src="/modules/gsnippetsreviews/js/jquery.star-rating.js"></script>
#
#
#
# <script type="text/javascript">
# //<![CDATA[
# 	var error_label = "Erreur";
#     var page_name = "category";
# 	var is_swal = parseInt("1");
#     var ps_version = parseInt("1.5.6.2");
# //]]>
# </script>
# <style type="text/css">
# 		.abg_click_zone { z-index: -1; }
# 	body {
# 		background:  transparent;
# 	}
# </style>
# <!--[if lt IE 10]>
# <script type="text/javascript" src="/modules/pm_advancedbackgroundchanger/js/PIE.js"></script>
# <![endif]-->
#
# <script type="text/javascript">
# // <![CDATA[
#
#
# 	if ($.browser.msie  && parseInt($.browser.version, 10) <= 7) {
# 		$(document).ready(function() {
# 			var cssObj = {
# 				'position': 'absolute',
# 				'top': '0',
# 				'left': '0',
# 				'width': document.body.clientWidth+'px',
# 				'height': document.body.clientHeight+'px',
# 				'-pie-background': ' transparent '
# 			}
# 			$('body').append('<div id="ABG_MultipleBG"></div>');
# 			$('#ABG_MultipleBG').css(cssObj);
# 			$('#ABG_MultipleBG').each(function() { if (window.PIE) PIE.attach(this); });
# 		});
# 	}
#
# 		$(document).ready(function() {
# 			$.vegas('slideshow', {
# 				ZoneAsArray:[],
# 				delay:5000,
# 				backgrounds:[
# 															{
# 							id_slide: 12,
# 							src:'/modules/pm_advancedbackgroundchanger/uploads/slides/528e54f08cb76.jpg',
# 							fade:2000,
# 							fixedSize: 0,
# 							align: '50',
# 							valign: '50',
# 							attachement:  'fixed' ,
# 							complete:function() {
# 								setTimeout(function() {
# 									var img = [];
# 									if(img != false && img.length>0){
# 										for (var val in img) {
# 											$('a#abg_zone'+img[val]['id_czone']).css('display', "block");
# 										}
# 									} else {
# 										$('a[id^="abg_zone"]').css('display', "none");
# 									}
# 								}, 100);
# 							},
# 							load:function() {
# 								var img = [];
# 								if(img != false && img.length>0){
# 									for (var val in img) {
# 										$('a[id^="abg_zone"]:not([id$="e'+img[val]['id_czone']+'"])').css('display', "none");
# 									}
# 								} else {
# 									$('a[id^="abg_zone"]').css('display', "none");
# 								}
# 							}
# 						}
# 																			]
# 			 })
# 							('overlay', { src:'/modules/pm_advancedbackgroundchanger/img/overlays/1.png' });
# 						});
# // ]]>
# </script>
#
#
# <!--[if IE 8]>
# <style type="text/css">
#
# body {
#   -pie-background:
#
# 			 transparent  ;
#
#  	 /* behavior: url(/modules/pm_advancedbackgroundchanger/css/PIE.php); */
#  }
# </style>
# <script type="text/javascript">
#
# $(document).ready(function() {
# 	$('body').each(function() {
# 		if (window.PIE) PIE.attach(this);
# 	});
# });
#
# </script>
# <![endif]-->
# 	</head>
#
# <body id="category">
# 			<div id="page" class="container_9 clearfix">
# 			<div class="page_main">
# 			<div id="header" class="grid_9 alpha omega">
# 				<a id="header_logo" href="https://www.excellencerhum.com/" title="ExcellenceRhum">
# 						<!--<img  class="logo" src="https://cdn1.excellencerhum.com/img/logo_vecto_xmas.png" alt="ExcellenceRhum" width="425px" height="76px"/> -->
# 					    <img class="logo" src="https://cdn1.excellencerhum.com/img/logo-excellencerhum.png" alt="ExcellenceRhum" width="425px" height="72px"/>
# 				</a>
# 				<div id="header_right" class="grid_6 omega">
#
# <div id="languages_block_top">
# 	<div id="countries">
#
# 				<p class="selected_language">
# 			<img src="https://cdn3.excellencerhum.com/img/l/5.jpg" alt="fr" width="16" height="11" />
# 		</p>
# 						<ul id="first-languages" class="countries_ul">
# 					<li >
# 																<a href="https://www.excellencerhum.com/en/43-martinique" title="English (English)">
# 												<img src="https://cdn3.excellencerhum.com/img/l/1.jpg" alt="en" width="16" height="11" />
# 							</a>
# 						</li>
# 					<li class="selected_language">
# 								<img src="https://cdn3.excellencerhum.com/img/l/5.jpg" alt="fr" width="16" height="11" />
# 						</li>
# 					<li >
# 																<a href="https://www.excellencerhum.com/it/43-martinique" title="Italiano (Italian)">
# 												<img src="https://cdn3.excellencerhum.com/img/l/6.jpg" alt="it" width="16" height="11" />
# 							</a>
# 						</li>
# 					<li >
# 																<a href="https://www.excellencerhum.com/de/43-martinique" title="Deutsch (German)">
# 												<img src="https://cdn3.excellencerhum.com/img/l/7.jpg" alt="de" width="16" height="11" />
# 							</a>
# 						</li>
# 					<li >
# 																<a href="https://www.excellencerhum.com/es/43-martinique" title="Español (Spanish)">
# 												<img src="https://cdn3.excellencerhum.com/img/l/9.jpg" alt="es" width="16" height="11" />
# 							</a>
# 						</li>
# 				</ul>
# 	</div>
# </div>
#
# <script type="text/javascript">
# $(document).ready(function () {
# 	$("#countries").mouseover(function(){
# 		$(this).addClass("countries_hover");
# 		$(".countries_ul").addClass("countries_ul_hover");
# 	});
# 	$("#countries").mouseout(function(){
# 		$(this).removeClass("countries_hover");
# 		$(".countries_ul").removeClass("countries_ul_hover");
# 	});
#
# });
# </script>
#
# <script type="text/javascript">
# $(document).ready(function () {
# 	$("#setCurrency").mouseover(function(){
# 		$(this).addClass("countries_hover");
# 		$(".currencies_ul").addClass("currencies_ul_hover");
# 	});
# 	$("#setCurrency").mouseout(function(){
# 		$(this).removeClass("countries_hover");
# 		$(".currencies_ul").removeClass("currencies_ul_hover");
# 	});
#
# 	$('ul#first-currencies li:not(.selected)').css('opacity', 0.3);
# 	$('ul#first-currencies li:not(.selected)').hover(function(){
# 		$(this).css('opacity', 1);
# 	}, function(){
# 		$(this).css('opacity', 0.3);
# 	});
# });
# </script>
#
# <div id="currencies_block_top">
# 	<form id="setCurrency" action="/fr/43-martinique" method="post">
# 		<p>
# 			<input type="hidden" name="id_currency" id="id_currency" value=""/>
# 			<input type="hidden" name="SubmitCurrency" value="" />
# 			€
# 		</p>
# 		<ul id="first-currencies" class="currencies_ul">
# 							<li >
# 					<a href="javascript:setCurrency(1);" title="Dollar">USD$</a>
# 				</li>
# 							<li >
# 					<a href="javascript:setCurrency(7);" title="Dollar">AUD$</a>
# 				</li>
# 							<li >
# 					<a href="javascript:setCurrency(5);" title="Dollar (CAD)">CAD$</a>
# 				</li>
# 							<li class="selected">
# 					<a href="javascript:setCurrency(2);" title="Euro">€</a>
# 				</li>
# 							<li >
# 					<a href="javascript:setCurrency(6);" title="Franc">CHF</a>
# 				</li>
# 							<li >
# 					<a href="javascript:setCurrency(4);" title="Krona">kr</a>
# 				</li>
# 							<li >
# 					<a href="javascript:setCurrency(3);" title="Pound">£</a>
# 				</li>
# 							<li >
# 					<a href="javascript:setCurrency(8);" title="Yen">JPY¥</a>
# 				</li>
# 							<li >
# 					<a href="javascript:setCurrency(9);" title="Yuan">CNY¥</a>
# 				</li>
# 					</ul>
# 	</form>
# </div>
#
# <ul id="header_links">
# 	<li id="header_link_home"><a href="https://www.excellencerhum.com/" title="ExcellenceRhum" >accueil</a></li>
# 	<li id="header_link_specialproduct"><a href="https://www.excellencerhum.com/fr/promotions" title="Découvrez nos rhums et accessoires de dégustation en promotion" >promotions</a></li>
# 	<li id="header_link_sitemap"><a href="https://www.excellencerhum.com/fr/nouveaux-produits" title="Nouveautés : rhums et accessoires" class="active">nouveautés</a></li>
# 	<li id="header_link_sitemap"><a href="https://www.excellencerhum.com/fr/precommande" title="Ne manquez pas une occasion, réservez votre bouteille" >précommande</a></li>
# 	<li id="header_link_sitemap"><a href="https://www.excellencerhum.com/fr/infos/70-notre-boutique-paris" title="La boutique">La boutique</a></li>
# 	<li id="header_link_contact"><a href="https://www.excellencerhum.com/fr/contactez-nous" title="Parlons de rhum ensemble, posez nous vos questions" >Contactez-nous</a></li>
# </ul>
#
#
# <!-- Block search module TOP -->
# <div id="search_block_top" class="jolisearch col-sm-4 clearfix" itemscope itemtype="http://schema.org/WebSite">
# 	<meta itemprop="url" content="https://www.excellencerhum.com/"/>
# 	<form method="get" action="https://www.excellencerhum.com/fr/recherche" id="searchbox" itemprop="potentialAction" itemscope itemtype="http://schema.org/SearchAction">
# 			<meta itemprop="target" content="https://www.excellencerhum.com/fr/recherche?search_query={search_query}"/>
#
# 						<input type="hidden" name="controller" value="jolisearch" />
# 			<input type="hidden" name="module" value="ambjolisearch" />
# 			<input type="hidden" name="fc" value="module" />
#
# 			<input type="hidden" name="orderby" value="quantity" />
# 			<input type="hidden" name="orderway" value="desc" />
# 			<input type="hidden" name="p" value="1" />
#
# 			<input  itemprop="query-input" class="search_query form-control" type="text" id="search_query_top" name="search_query" value="" data-autocomplete="https://www.excellencerhum.com/fr/recherche" data-lang='5' data-manufacturer="Nos marques & distilleries" data-product="Nos produits" data-category="Nos catégories" data-no-results-found="Aucun produit ne correspond à cette recherche"  data-more-results="Montrer tous les résultats »" placeholder="Rechercher un rhum, une marque, une distillerie..."  />
#
# 			<!--<input type="submit" name="submit_search" value="Rechercher" class="button btn btn-default button-search" />-->
#
# 		 	<button type="submit" name="submit_search" class="p-btn p-btn--white p-btn--icon" style="
#     width: 40px!important;
#     height: 41px;
#     margin-left: -4px;
#     border-width: 1px 1px 1px 1px!important;
#     padding-left: 35px!important;
#     border-radius: 3px!important;
#     border-color: #CECECE!important;
# ">
# 				<i class="icon-search"></i>
# 			</button>
#
# 	</form>
#
# </div>
#
# <!-- /Block search module TOP -->
#
#
# <div id="header_user">
# 	<ul id="header_nav">
# 				<li id="shopping_cart">
# 			<a href="https://www.excellencerhum.com/fr/commande" title="Voir mon panier" rel="nofollow">
# 			<span class="ajax_cart_product_title">Panier</span>
# 			<span class="ajax_cart_quantity hidden">0</span>
# 			<span class="ajax_cart_product_txt hidden">produit</span>
# 			<span class="ajax_cart_product_txt_s hidden">produits</span>
# 			<span class="ajax_cart_total hidden">
# 							</span>
# 			<span class="ajax_cart_no_product">(vide)</span>
# 			</a>
# 		</li>
# 				<li id="your_account">
# 			<p id="header_user_info">
# 			Bienvenue,
# 							<a href="https://www.excellencerhum.com/fr/mon-compte" title="Se connecter à votre compte client" class="login" rel="nofollow">identifiez-vous</a>
# 						</p>
# 			<a class="title_your" href="https://www.excellencerhum.com/fr/mon-compte" title="Consulter mon compte client" rel="nofollow">Votre compte</a>
#
# 		</li>
# 	</ul>
#
# </div>
# 		<div class="chatwithus"><a href="tel:+33%201%2085%2041%2011%2020">+33 1 85 41 11 20</a>
# <p>besoin d'aide ?</p>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var CUSTOMIZE_TEXTFIELD = 1;
# var img_dir = 'https://cdn1.excellencerhum.com/themes/ExcellenceRhum/img/';
# </script>
# <script type="text/javascript">
# var customizationIdMessage = 'Personnalisation';
# var removingLinkText = 'supprimer cet article du panier';
# var freeShippingTranslation = 'Livraison Gratuite';
# var freeProductTranslation = 'Gratuit!';
# var delete_txt = 'Supprimer';
# </script>
#
#
# <!-- MODULE Block cart -->
# <div id="cart_block" class="exclusive">
# 	<h4>
# 		<a href="https://www.excellencerhum.com/fr/commande">Panier</a>
# 				<span id="block_cart_expand" class="hidden">&nbsp;</span>
# 		<span id="block_cart_collapse" >&nbsp;</span>
# 			</h4>
# 	<div class="block_content">
# 	<!-- block summary -->
# 	<div id="cart_block_summary" class="collapsed">
# 		<span class="ajax_cart_quantity" style="display:none;">0</span>
# 		<span class="ajax_cart_product_txt_s" style="display:none">articles</span>
# 		<span class="ajax_cart_product_txt" >article</span>
# 		<span class="ajax_cart_total" style="display:none">
# 					</span>
# 		<span class="ajax_cart_no_product" >(vide)</span>
# 	</div>
# 	<!-- block list of products -->
# 	<div id="cart_block_list" class="expanded">
# 			<p  id="cart_block_no_products">Aucun produit</p>
#
# 		<div id="cart-prices">
# 			<p>
# 				<span class="title">Frais de port</span>
# 				<span id="cart_block_shipping_cost" class="price ajax_cart_shipping_cost">0,00 €</span>
# 			</p>
#
#
# 						<p>
# 				<span class="title">Total</span>
# 				<span id="cart_block_total" class="price ajax_block_cart_total">0,00 €</span>
# 			</p>
# 		</div>
# 				<p id="cart-buttons">
# 			<a href="https://www.excellencerhum.com/fr/commande" class="button_small" title="Voir mon panier" rel="nofollow">Panier</a>			<a href="https://www.excellencerhum.com/fr/commande" id="button_order_cart" class="exclusive" title="Commander" rel="nofollow"><span>Commander</span></a>
# 		</p>
# 	</div>
# 	</div>
# </div>
# <!-- /MODULE Block cart -->
#
# </div>
# <div class="clear"></div>
# <div id="adtm_menu">
# <div id="adtm_menu_inner">
# <ul id="menu">
# <li class="li-niveau1 advtm_menu_1  sub"><a href="/" title="Accueil &amp; s&eacute;lection" target="_parent" class=" a-niveau1"><span class="advtm_menu_span advtm_menu_span_1">Accueil &amp; s&eacute;lection</span><!--[if gte IE 7]><!--></a><!--<![endif]-->
# <!--[if lte IE 6]><table><tr><td><![endif]-->
# 	<div class="adtm_sub">
# 				<table class="columnWrapTable"><tr>
# 									<td class="adtm_column_wrap_td advtm_column_wrap_td_5">
# 				<div class="adtm_column_wrap advtm_column_wrap_5">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 																											<div class="adtm_column adtm_column_22">
# 						<h5><a href="#" title=""  class="adtm_unclickable"></a></h5>																			<ul class="adtm_elements adtm_elements_22">
# 																								<li><a href="/fr/promotions" title="Promotions &amp; bonnes affaires"  class="">Promotions &amp; bonnes affaires</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/84-coffrets-cadeaux-avec-verres-de-degustation" title="Les coffrets avec verres"  class="">Les coffrets avec verres</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/212-cave-a-rhum" title="Cave &agrave; Rhum &amp; Pack"  class="">Cave &agrave; Rhum &amp; Pack</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/88-la-selection-d-excellencerhum" title="La selection d'ExcellenceRhum"  class="">La selection d'ExcellenceRhum</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/91-idees-cadeaux" title="Id&eacute;es cadeaux"  class="">Id&eacute;es cadeaux</a></li>
# 																						</ul>
# 												</div>
#
# 																											<div class="adtm_column adtm_column_120">
# 						<h5><a href="#" title="Age &amp; Mill&eacute;sime"  class="adtm_unclickable">Age &amp; Mill&eacute;sime</a></h5>																			<ul class="adtm_elements adtm_elements_120">
# 																								<li><a href="/fr/69-millesimes-rhum#s[6][]:10-10&amp;s[3][]:838&amp;ash[3][]:838&amp;rg:&amp;sid:4&amp;h:rightColumn&amp;ics:69&amp;abs:YToxOntpOjA7aTo4Mzg7fQ::" title="10"  class="">10</a></li>
# 																																<li><a href="/fr/69-millesimes-rhum#s[6][]:18-18&amp;s[3][]:838&amp;ash[3][]:838&amp;rg:&amp;sid:4&amp;h:rightColumn&amp;ics:69&amp;abs:YToxOntpOjA7aTo4Mzg7fQ::" title="18"  class="">18</a></li>
# 																																<li><a href="/fr/69-millesimes-rhum#s[6][]:20-20&amp;s[3][]:838&amp;ash[3][]:838&amp;rg:&amp;sid:4&amp;h:rightColumn&amp;ics:69&amp;abs:YToxOntpOjA7aTo4Mzg7fQ::" title="20"  class="">20</a></li>
# 																																<li><a href="/fr/69-millesimes-rhum#s[6][]:25-25&amp;s[3][]:838&amp;ash[3][]:838&amp;rg:&amp;sid:4&amp;h:rightColumn&amp;ics:69&amp;abs:YToxOntpOjA7aTo4Mzg7fQ::" title="25"  class="">25</a></li>
# 																																<li><a href="/fr/69-millesimes-rhum#s[6][]:30-30&amp;rg:&amp;sid:4&amp;h:rightColumn&amp;ics:69" title="30"  class="">30</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/69-millesimes-rhum#s[5][]:1045&amp;s[4][]:970&amp;s[6][]:&amp;rg:&amp;sid:4&amp;h:rightColumn&amp;ics:69" title="1979"  class="">1979</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/69-millesimes-rhum#s[5][]:1045&amp;s[4][]:920&amp;s[6][]:&amp;rg:&amp;sid:4&amp;h:rightColumn&amp;ics:69" title="1988"  class="">1988</a></li>
# 																																<li><a href="/fr/69-millesimes-rhum#s[5][]:1045&amp;s[4][]:928&amp;s[6][]:&amp;rg:&amp;sid:4&amp;h:rightColumn&amp;ics:69" title="1997"  class="">1997</a></li>
# 																																<li><a href="/fr/69-millesimes-rhum#s[4][]:931&amp;s[6][]:&amp;s[3][]:838&amp;ash[3][]:838&amp;rg:&amp;sid:4&amp;h:rightColumn&amp;ics:69&amp;abs:YToxOntpOjA7aTo4Mzg7fQ::" title="2000"  class="">2000</a></li>
# 																						</ul>
# 												</div>
#
# 																											<div class="adtm_column adtm_column_121">
# 						<h5><a href="#" title=""  class="adtm_unclickable"></a></h5>																			<ul class="adtm_elements adtm_elements_121">
# 																								<li><a href="https://www.excellencerhum.com/fr/69-millesimes-rhum" title="Mill&eacute;simes &amp; &acirc;ge de votre naissance"  class="">Mill&eacute;simes &amp; &acirc;ge de votre naissance</a></li>
# 																						</ul>
# 												</div>
#
# 												</div>
# 				</td>
# 												<td class="adtm_column_wrap_td advtm_column_wrap_td_8">
# 				<div class="adtm_column_wrap advtm_column_wrap_8">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 																											<div class="adtm_column adtm_column_19">
# 						<h5><a href="#" title="Couleur"  class="adtm_unclickable">Couleur</a></h5>																			<ul class="adtm_elements adtm_elements_19">
# 																								<li><a href="/fr/s/5/rhum-blanc" title=" Rhum blanc"  class=""><img src="/modules/pm_advancedtopmenu/element_icons/266.png" alt=" Rhum blanc" title=" Rhum blanc" class="adtm_menu_icon" /> Rhum blanc</a></li>
# 																																<li><a href="/fr/s/7/rhum-paille-dore" title=" Rhum Paille"  class=""><img src="/modules/pm_advancedtopmenu/element_icons/5.png" alt=" Rhum Paille" title=" Rhum Paille" class="adtm_menu_icon" /> Rhum Paille</a></li>
# 																																<li><a href="/fr/s/12/rhums-ambres" title=" Rhum Ambr&eacute;"  class=""><img src="/modules/pm_advancedtopmenu/element_icons/4.png" alt=" Rhum Ambr&eacute;" title=" Rhum Ambr&eacute;" class="adtm_menu_icon" /> Rhum Ambr&eacute;</a></li>
# 																																<li><a href="/fr/s/13/rhums-dark" title=" Rhum Brun / Dark rum"  class=""><img src="/modules/pm_advancedtopmenu/element_icons/267.png" alt=" Rhum Brun / Dark rum" title=" Rhum Brun / Dark rum" class="adtm_menu_icon" /> Rhum Brun / Dark rum</a></li>
# 																						</ul>
# 												</div>
#
# 																											<div class="adtm_column adtm_column_25">
# 						<h5><a href="#" title="Prix"  class="adtm_unclickable">Prix</a></h5>																			<ul class="adtm_elements adtm_elements_25">
# 																								<li><a href="/fr/s/2/rhum-pas-cher" title="Moins de 29 &euro;"  class="">Moins de 29 &euro;</a></li>
# 																																<li><a href="/fr/s/1/rhum-prix-29-49" title="29 - 49 &euro;"  class="">29 - 49 &euro;</a></li>
# 																																<li><a href="/fr/s/3/rhum-prix-49-99" title="49 - 99 &euro;"  class="">49 - 99 &euro;</a></li>
# 																																<li><a href="/fr/s/9/rhum-100-et-plus" title="Plus de 100 &euro;"  class="">Plus de 100 &euro;</a></li>
# 																						</ul>
# 												</div>
#
# 																											<div class="adtm_column adtm_column_86">
# 						<h5><a href="#" title="Contenances"  class="adtm_unclickable">Contenances</a></h5>																			<ul class="adtm_elements adtm_elements_86">
# 																								<li><a href="https://www.excellencerhum.com/fr/s/16/petites-contenances-rhum" title="Nos samples (taste-me, tubes)"  class="">Nos samples (taste-me, tubes)</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/s/17/mignonette-rhum" title="Nos mignonettes de rhum"  class="">Nos mignonettes de rhum</a></li>
# 																																<li><a href="/fr/s/18/magnum-cubi-rhum" title="Magnum, R&eacute;hoboam, J&eacute;roboam &amp; Cubi"  class="">Magnum, R&eacute;hoboam, J&eacute;roboam &amp; Cubi</a></li>
# 																						</ul>
# 												</div>
#
# 												</div>
# 				</td>
# 												<td class="adtm_column_wrap_td advtm_column_wrap_td_7">
# 				<div class="adtm_column_wrap advtm_column_wrap_7">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 																											<div class="adtm_column adtm_column_118">
# 						<h5><a href="#" title="Le rhum dans tous ses &eacute;tats"  class="adtm_unclickable">Le rhum dans tous ses &eacute;tats</a></h5>																			<ul class="adtm_elements adtm_elements_118">
# 																								<li><a href="https://www.excellencerhum.com/fr/s/56/rhum-bio" title="Rhum bio"  class="">Rhum bio</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/s/55/rhum-brut-de-fut" title="Brut de f&ucirc;t"  class="">Brut de f&ucirc;t</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/s/61/vieillissement-tropical" title="Vieillissement 100% Tropical"  class="">Vieillissement 100% Tropical</a></li>
# 																																<li><a href="/fr/s/62/rhum-fut-unique" title="F&ucirc;t unique / Single Cask"  class="">F&ucirc;t unique / Single Cask</a></li>
# 																						</ul>
# 												</div>
#
# 																											<div class="adtm_column adtm_column_117">
# 						<h5><a href="#" title="Les finitions"  class="adtm_unclickable">Les finitions</a></h5>																			<ul class="adtm_elements adtm_elements_117">
# 																								<li><a href="https://www.excellencerhum.com/fr/s/57/finition-sauternes" title="Sauternes"  class="">Sauternes</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/s/58/finition-cognac" title="Cognac"  class="">Cognac</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/s/59/finition-porto" title="Porto"  class="">Porto</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/s/60/whisky-finition" title="Whisky"  class="">Whisky</a></li>
# 																						</ul>
# 												</div>
#
# 																											<div class="adtm_column adtm_column_122">
# 						<h5><a href="#" title="Rhum mono-varietal"  class="adtm_unclickable">Rhum mono-varietal</a></h5>																			<ul class="adtm_elements adtm_elements_122">
# 																								<li><a href="/fr/s/63/rhum-canne-bleue" title="Canne bleue"  class="">Canne bleue</a></li>
# 																																<li><a href="/fr/s/65/rhum-canne-rouge" title="Canne rouge"  class="">Canne rouge</a></li>
# 																																<li><a href="/fr/s/64/rhum-canne-noire" title="Canne noire"  class="">Canne noire</a></li>
# 																						</ul>
# 												</div>
#
# 																											<div class="adtm_column adtm_column_21">
# 						<h5><a href="#" title="Les insolites"  class="adtm_unclickable">Les insolites</a></h5>																			<ul class="adtm_elements adtm_elements_21">
# 																								<li><a href="https://www.excellencerhum.com/fr/92-les-collectionnables" title="Les Collectionnables"  class="">Les Collectionnables</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/s/6/rhum-fort-70-degres" title="Les rhums forts en alcool (+ de 70%)"  class="">Les rhums forts en alcool (+ de 70%)</a></li>
# 																						</ul>
# 												</div>
#
# 												</div>
# 				</td>
# 							</tr></table>
# 			</div>
# <!--[if lte IE 6]></td></tr></table></a><![endif]-->
# </li>
# <li class="li-niveau1 advtm_menu_36  sub"><a href="#" title="Autres Spiritueux"  class="adtm_unclickable a-niveau1"><span class="advtm_menu_span advtm_menu_span_36">Autres Spiritueux</span><!--[if gte IE 7]><!--></a><!--<![endif]-->
# <!--[if lte IE 6]><table><tr><td><![endif]-->
# 	<div class="adtm_sub">
# 				<table class="columnWrapTable"><tr>
# 									<td class="adtm_column_wrap_td advtm_column_wrap_td_77">
# 				<div class="adtm_column_wrap advtm_column_wrap_77">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 																											<div class="adtm_column adtm_column_140">
# 						<h5><a href="#" title=""  class="adtm_unclickable"></a></h5>																			<ul class="adtm_elements adtm_elements_140">
# 																								<li><a href="https://www.excellencerhum.com/fr/106-whisky-bourbon" title="Whisky"  class="">Whisky</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/100-cognac" title="Cognac"  class="">Cognac</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/115-gin" title="Gin"  class="">Gin</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/101-calvados" title="Calvados"  class="">Calvados</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/102-armagnac" title="Armagnac"  class="">Armagnac</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/112-champagne" title="Champagne"  class="">Champagne</a></li>
# 																						</ul>
# 												</div>
#
# 												</div>
# 				</td>
# 												<td class="adtm_column_wrap_td advtm_column_wrap_td_79">
# 				<div class="adtm_column_wrap advtm_column_wrap_79">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 																											<div class="adtm_column adtm_column_142">
# 						<h5><a href="#" title="Whisky &amp; Bourbon"  class="adtm_unclickable">Whisky &amp; Bourbon</a></h5>																			<ul class="adtm_elements adtm_elements_142">
# 																								<li><a href="https://www.excellencerhum.com/fr/133-ecosse" title="Whisky d'&eacute;cosse"  class="">Whisky d'&eacute;cosse</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/228-japon" title="Whisky Japonais"  class="">Whisky Japonais</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/169-irlande" title="Whisky Irlandais"  class="">Whisky Irlandais</a></li>
# 																						</ul>
# 												</div>
#
# 																											<div class="adtm_column adtm_column_143">
# 						<h5><a href="#" title="Mais aussi"  class="adtm_unclickable">Mais aussi</a></h5>																			<ul class="adtm_elements adtm_elements_143">
# 																								<li><a href="https://www.excellencerhum.com/fr/171-eaux-de-vie" title="Eaux de vie"  class="">Eaux de vie</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/118-vodka" title="Vodka"  class="">Vodka</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/99-tequila-mezcal-et-sotol" title="Tequila, Mezcal et Sotol"  class="">Tequila, Mezcal et Sotol</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/122-absinthes" title="Absinthes"  class="">Absinthes</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/170-aperitifs-amers-vermouth" title="Aperitifs, Amers &amp; Vermouth"  class="">Aperitifs, Amers &amp; Vermouth</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/284-liqueur-cremes" title="Liqueur &amp; Cr&egrave;mes"  class="">Liqueur &amp; Cr&egrave;mes</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/120-sake-sochu" title="Sak&eacute; &amp; Sochu"  class="">Sak&eacute; &amp; Sochu</a></li>
# 																																<li><a href="https://www.excellencerhum.com/fr/130-akuavit" title="Akuavit"  class="">Akuavit</a></li>
# 																						</ul>
# 												</div>
#
# 												</div>
# 				</td>
# 												<td class="adtm_column_wrap_td advtm_column_wrap_td_80">
# 				<div class="adtm_column_wrap advtm_column_wrap_80">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 													<div class="adtm_column">
# <h5 style="text-align: center;"><a class="adtm_unclickable" title="">Notre selection</a></h5>
# <p style="text-align: center; font-family: Georgia; font-size: 13px; color: #727272; font-weight: 100;">Eau-de-vie de Pêche Plate (<em>Pesche Saturno</em>) réalisée par l'un des meilleur distillateur au monde : Capovilla</p>
# <p style="text-align: center; margin-top: -5px;"><a class="product_img_link label inside bottom float" title="Capovilla Pesche Saturno" href="/fr/eaux-de-vie/1142-rhum-capovilla-peche-plate-pesche-saturno.html"> <img src="https://cdn3.excellencerhum.com/5974-home_default/rhum-capovilla-peche-plate-pesche-saturno.jpg" alt="Capovilla Pesche Saturno" /></a></p>
# </div>
# <p><a class="button" style="font-family: Arial, Helvetica, Sans-Serif; margin: auto; text-transform: uppercase;" title="Découvrir cette eau-de-vie Capovilla Pesche Saturno" href="/fr/eaux-de-vie/1142-rhum-capovilla-peche-plate-pesche-saturno.html">Voir le spiritueux</a></p>
# 								</div>
# 				</td>
# 							</tr></table>
# 			</div>
# <!--[if lte IE 6]></td></tr></table></a><![endif]-->
# </li>
# <li class="li-niveau1 advtm_menu_5  sub"><a href="/fr/7-caraibe" title="rhums des Cara&iuml;bes"  class=" a-niveau1"><span class="advtm_menu_span advtm_menu_span_5">rhums des Cara&iuml;bes</span><!--[if gte IE 7]><!--></a><!--<![endif]-->
# <!--[if lte IE 6]><table><tr><td><![endif]-->
# 	<div class="adtm_sub">
# 				<table class="columnWrapTable"><tr>
# 									<td class="adtm_column_wrap_td advtm_column_wrap_td_3">
# 				<div class="adtm_column_wrap advtm_column_wrap_3">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 													<div class="adtm_column adtm_column_87">
# <h5><a title="rhum caraïbes" href="/fr/7-caraibe">Rhum des Caraïbes</a></h5>
# </div>
# <ul class="adtm_elements adtm_elements_87">
# <li><a title="Rhum de Martinique" href="/fr/43-martinique">Martinique</a></li>
# <li><a title="Guadeloupe" href="/fr/44-guadeloupe">Guadeloupe</a></li>
# <li><a title="Marie Galante " href="/fr/45-marie-galante">Marie Galante </a></li>
# <li><a title="Trinité-et-Tobago" href="/fr/8-trinite-et-tobago">Trinité-et-Tobago</a></li>
# <li><a title="Cuba" href="/fr/75-cuba">Cuba</a></li>
# <li><a title="Barbade" href="/fr/79-barbade">Barbade</a></li>
# <li><a title="Saint-Vincent-et-les Grenadines" href="/fr/9-saint-vincent-et-les-grenadines">St-Vincent-et-les Grenadines</a></li>
# <li><a title="Anguilla" href="/fr/74-anguilla">Anguilla</a></li>
# <li><a title="Antigua-et-Barbuda" href="/fr/82-antigua-et-barbuda">Antigua-et-Barbuda</a></li>
# <li><a title="Saint-Christophe-et-Niévès" href="/fr/292-saint-christophe-et-nieves">Saint-Christophe-et-Niévès</a></li>
# </ul>
# 								</div>
# 				</td>
# 												<td class="adtm_column_wrap_td advtm_column_wrap_td_4">
# 				<div class="adtm_column_wrap advtm_column_wrap_4">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 													<div class="adtm_column"> </div>
# <ul class="adtm_elements adtm_elements_11">
# <li><a title="Jamaique" href="/fr/13-jamaique">Jamaique</a></li>
# <li><a title="Haïti" href="/fr/76-haiti">Haïti</a></li>
# <li><a title="Puerto Rico" href="/fr/77-puerto-rico">Puerto Rico</a></li>
# <li><a title="Îles Vierges des États-Unis" href="/fr/14-iles-vierges-des-etats-unis">Îles Vierges des États-Unis</a></li>
# <li><a title="St Martin et St Barth" href="/fr/47-st-martin-et-st-barth">St Martin et St Barth</a></li>
# <li><a title="Sainte Lucie" href="/fr/10-sainte-lucie">Sainte Lucie</a></li>
# <li><a title="Republique Dominicaine" href="/fr/12-republique-dominicaine">Republique Dominicaine<br /></a></li>
# <li><a title="Bermudes" href="/fr/83-bermudes">Bermudes</a></li>
# <li><a title="îles Vierges britannique" href="/fr/289-iles-vierges-britanniques">îles Vierges britanniques</a></li>
# </ul>
# 								</div>
# 				</td>
# 												<td class="adtm_column_wrap_td advtm_column_wrap_td_24">
# 				<div class="adtm_column_wrap advtm_column_wrap_24">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 													<div class="adtm_column">
# <h5 style="text-align: center;"><a class="adtm_unclickable" title="">Coffret découverte</a></h5>
# <p style="text-align: center; font-family: Georgia; font-size: 13px; color: #727272; font-weight: 100;">Partez à la découverte des rhums agricoles grâce à ce coffret de 5 rhums</p>
# <p style="text-align: center; margin-top: -5px;"><a class="product_img_link label inside bottom float" title="coffret sample rhum agricole" href="https://www.excellencerhum.com/fr/sample-tubes/3092-coffret-sample-rhum-agricole.html"> <img src="https://cdn3.excellencerhum.com/3246-home_default/coffret-sample-agricole.jpg" alt="Coffret sample rhum agricole" /></a></p>
# </div>
# <p><a class="button" style="font-family: Arial, Helvetica, Sans-Serif; margin: auto; text-transform: uppercase;" title="Découvrir ce coffret" href="https://www.excellencerhum.com/fr/sample-tubes/3092-coffret-sample-rhum-agricole.html">découvrir</a></p>
# 								</div>
# 				</td>
# 												<td class="adtm_column_wrap_td advtm_column_wrap_td_54">
# 				<div class="adtm_column_wrap advtm_column_wrap_54">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 													<div class="adtm_column">
# <h5><a class="adtm_unclickable" title="distillerie à la une" href="#">Distillerie à la une</a></h5>
# </div>
# <ul class="adtm_elements">
# <li><a title="La Favorite" href="/fr/28_la-favorite">La Favorite</a></li>
# <li><a title="Saint James" href="/fr/38_saint-james">Saint James</a></li>
# <li><a title="HSE" href="/fr/25_habitation-saint-etienne">Habitation Saint Etienne</a></li>
# <li><a title="Caroni" href="/fr/105_caroni">Caroni</a></li>
# </ul>
# <div class="adtm_column">
# <h5><a class="adtm_unclickable" title="Top5 Caraïbes" href="#">Top5 Caraïbes</a></h5>
# </div>
# <ul class="adtm_elements">
# <li><a title="Foursquare 2005" href="/fr/barbade/4038-rhum-foursquare-2005.html">Foursquare 2005</a></li>
# <li><a title="Damoiseau 1995" href="/fr/guadeloupe/3474-rhum-agricole-damoiseau-millesime-1995.html">Damoiseau 1995</a></li>
# <li><a title="Barbancourt 15 ans" href="/fr/haiti/138-rhum-barbancourt-reserve-du-domaine-15-ans.html">Barbancourt 15 ans</a></li>
# <li><a title="Smith &amp; Cross" href="/fr/jamaique/260-rhum-smith-cross-navy-strength.html">Smith &amp; Cross</a></li>
# <li><a title="Caroni 21 ans Velier" href="/fr/trinite-et-tobago/3946-rhum-velier-caroni-millesime-1996-21-ans.html">Caroni 21 ans</a></li>
# </ul>
# 								</div>
# 				</td>
# 							</tr></table>
# 			</div>
# <!--[if lte IE 6]></td></tr></table></a><![endif]-->
# </li>
# <li class="li-niveau1 advtm_menu_6  sub"><a href="https://www.excellencerhum.com/fr/15-amerique-latine" title="Am&eacute;rique latine"  class=" a-niveau1"><span class="advtm_menu_span advtm_menu_span_6">Am&eacute;rique latine</span><!--[if gte IE 7]><!--></a><!--<![endif]-->
# <!--[if lte IE 6]><table><tr><td><![endif]-->
# 	<div class="adtm_sub">
# 				<table class="columnWrapTable"><tr>
# 									<td class="adtm_column_wrap_td advtm_column_wrap_td_26">
# 				<div class="adtm_column_wrap advtm_column_wrap_26">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 													<div class="adtm_column">
# <h5><a title="rhum Amérique Latine" href="/fr/15-amerique-latine">Rhum d'Amérique Latine</a></h5>
# </div>
# <ul class="adtm_elements">
# <li><a title="Venezuela" href="/fr/16-venezuela">Venezuela</a></li>
# <li><a title="Bélize" href="/fr/90-belize">Bélize</a></li>
# <li><a title="Brésil" href="/fr/27-bresil">Brésil</a></li>
# <li><a title="Nicaragua" href="/fr/19-nicaragua">Nicaragua</a></li>
# <li><a title="Paraguay" href="/fr/81-paraguay">Paraguay</a></li>
# <li><a title="Mexique" href="/fr/20-mexique">Mexique</a></li>
# <li><a title="Panama" href="/fr/17-panama">Panama<br /></a></li>
# </ul>
# 								</div>
# 				</td>
# 												<td class="adtm_column_wrap_td advtm_column_wrap_td_27">
# 				<div class="adtm_column_wrap advtm_column_wrap_27">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 													<div class="adtm_column"> </div>
# <ul class="adtm_elements">
# <li><a title="Pérou" href="/fr/80-perou">Pérou</a></li>
# <li><a title="Guatemala" href="/fr/22-guatemala">Guatemala</a></li>
# <li><a title="Equateur" href="/fr/23-equateur">Equateur</a></li>
# <li><a title="Colombie" href="/fr/24-colombie">Colombie</a></li>
# <li><a href="/fr/21-guyane">Guyane Française</a></li>
# <li><a href="/fr/126-guyana">Guyana (Guyane Britannique)</a></li>
# <li><a title="Costa Rica" href="/fr/25-costa-rica">Costa Rica</a></li>
# </ul>
# 								</div>
# 				</td>
# 												<td class="adtm_column_wrap_td advtm_column_wrap_td_10">
# 				<div class="adtm_column_wrap advtm_column_wrap_10">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 													<div class="adtm_column">
# <h5 style="text-align: center;"><a class="adtm_unclickable" title="">Nouveauté</a></h5>
# <p style="text-align: center; font-family: Georgia; font-size: 13px; color: #727272; font-weight: 100;">“<em>Lʼassemblage dʼeaux-de-vie constituent ce rhum est vieilli dans de très rares fûts de chênes...</em>”</p>
# <p style="text-align: center; margin-top: -5px;"><a class="product_img_link label inside bottom float" title="Zacapa Royal" href="/fr/guatemala/3754-rhum-zacapa-royal.html"> <img src="https://cdn3.excellencerhum.com/4481-home_default/rhum-zacapa-royal.jpg" alt="Zacapa Royal" /></a></p>
# </div>
# <p><a class="button" style="font-family: Arial, Helvetica, Sans-Serif; margin: auto; text-transform: uppercase;" title="Découvrir ce rhum Zacapa Royal" href="/fr/guatemala/3754-rhum-zacapa-royal.html">voir</a></p>
# 								</div>
# 				</td>
# 												<td class="adtm_column_wrap_td advtm_column_wrap_td_56">
# 				<div class="adtm_column_wrap advtm_column_wrap_56">
# 								<div class="adtm_column_wrap_sizer">&nbsp;</div>
# 													<div class="adtm_column">
# <h5><a class="adtm_unclickable" title="Marques à la une" href="#">Marques à la une</a></h5>
# </div>
# <ul class="adtm_elements">
# <li><a title="El Dorado Demerara" href="/fr/69_el-dorado-rum">El dorado</a></li>
# <li><a title="Abuelo" href="/fr/10_abuelo">Abuelo</a></li>
# ...
# 					<input type="submit" value="ok" class="button_mini" name="submitNewsletter" />
# 				<input type="hidden" name="action" value="0" />
# 			</p>
# 		</form>
# 	</div>
# </div>
# <!-- Block Customer Comments -->
# <div id="customer_comments_block_left" class="block">
#   <h4>Commentaires clients</h4>
#     <div class="slider">
# 	  <ul class="slides">
# 	    	    <li class="slide"><p>Mes cadeaux d'entreprise livré directement chez mes clients, c'est fabuleux, merci Excellencerhum pour son service 3 étoiles.<br><br>
# 	      <i>SARL David</i></p>
# 	    </li>
#       		    <li class="slide"><p>Bons conseils, emballage professionnel, reçu en 24h en Belgique ! <br><br>
# 	      <i>Dominique D.</i></p>
# 	    </li>
#       		    <li class="slide"><p>Commandé à 10h, reçu le lendemain avec plein d'échantillons, super service et bons conseils du service client.<br><br>
# 	      <i>Sylvie A.</i></p>
# 	    </li>
#       		    <li class="slide"><p>Ce site est parfait, 8 commandes et toujours reçu le lendemain, emballage très classe. Merci !<br><br>
# 	      <i>Joris B.</i></p>
# 	    </li>
#       		  </ul>
# 	</div>
# </div>
#
#
#
# <script type="text/javascript">
# $(window).load(function() {
#     $('.slider').glide({
#     arrowRightText: '→',
# 	arrowLeftText: '←',
# 	nav:false,
# 	autoplay:3000
# 	});
# });
# </script>
#
# <!-- Block Customer Comments -->    <div style="width: 100% !important;">    <div class="GSRBadge_colRight GSRBadge" style="color: black;">
# 		<div class="GSRMedal"></div>
#
#          <!--  review -->
#
#
#     		<script type="application/ld+json">
# {
#     "aggregateRating": {
#     "@type": "AggregateRating",
#     "ratingValue": "5",
#     "reviewCount": "568"
#   }
# }
# </script>
#
#         <span itemscope itemtype="http://data-vocabulary.org/Review-aggregate">
#             <span itemprop="itemreviewed">Rhum en provenance de la Martinique</span><br />
#                 <!-- <img itemprop="photo" src="" /> -->
#
#             <span itemprop="rating" itemscope itemtype="http://data-vocabulary.org/Rating">
# 				<span class="GSRBadgeRateBg" style="background: url(/modules/gsnippetsreviews/img/picto/4-thumbs-yellow/picto.gif) repeat-x;">
# 											<span class="GSRBadgeRateElement" style="background: url(/modules/gsnippetsreviews/img/picto/4-thumbs-yellow/picto.gif) no-repeat 0px -32px;"></span>
# 											<span class="GSRBadgeRateElement" style="background: url(/modules/gsnippetsreviews/img/picto/4-thumbs-yellow/picto.gif) no-repeat 0px -32px;"></span>
# 											<span class="GSRBadgeRateElement" style="background: url(/modules/gsnippetsreviews/img/picto/4-thumbs-yellow/picto.gif) no-repeat 0px -32px;"></span>
# 											<span class="GSRBadgeRateElement" style="background: url(/modules/gsnippetsreviews/img/picto/4-thumbs-yellow/picto.gif) no-repeat 0px -32px;"></span>
# 											<span class="GSRBadgeRateElement" style="background: url(/modules/gsnippetsreviews/img/picto/4-thumbs-yellow/picto.gif) no-repeat 0px -32px;"></span>
# 														</span><br />
#                 Moyenne:  <span itemprop="average">5</span> / <span itemprop="best">5</span><br />
#             </span>
#             Basé sur <span itemprop="votes">568</span> note(s)            	            et 548 avis client.
#                     </span>
#
#      <!--  END review -->
#
#     </div>
#     </div></div>								</div>
# 						</div>
#
# 			<div id="footer" class="grid_9 alpha omega clearfix">
# 				<div class="boder_main_footer">
# 						<div class="main_footer">
# <div id="freeblock" class="block"><a title="sample de rhum" href="https://www.excellencerhum.com/fr/250-sample-tubes"><img src="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/img/themes_speciaux/xmas_2015/footer.jpg" alt="sample, coffrets découverte" /></a></div>
# <div class="footer_cms_1">
# <div class="main_footer_cms_1">
# <div class="content_footer_cms_1">
# <div class="about">
# <h4>À propos d'Excellence Rhum</h4>
# <p class="img"><a href="https://www.excellencerhum.com/fr/infos/4-qui-sommes-nous"><img src="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/img/cms/about.jpg" alt="" width="204" height="85" /></a></p>
# <div class="des_store">
# <p>L’idée d’ExcellenceRhum est née : <br />Entre la Martinique et Sainte Lucie; <br />Entre effluves de fruits et doux parfums d'épices...</p>
# <p><a href="https://www.excellencerhum.com/fr/infos/4-qui-sommes-nous">Découvrez qui nous sommes ?</a></p>
# </div>
# </div>
# <div class="shopbycategory">
# <h4>PRODUITS PHARES</h4>
# <ul>
# <li><a title="Diplomatico Reserva Exclusiva" href="https://www.excellencerhum.com/fr/venezuela/139-rhum-diplomatico-reserva-exclusiva.html">Diplomatico Reserva Exclusiva</a></li>
# <li><a title="don papa rhum" href="https://www.excellencerhum.com/fr/philippines/314-rhum-don-papa-rhum-7-ans.html">Rhum Don Papa</a></li>
# <li><a title="Rhum angostura" href="https://www.excellencerhum.com/fr/20_angostura">Angostura</a></li>
# <li><a title="rhum Zacapa" href="https://www.excellencerhum.com/fr/guatemala/83-rhum-zacapa-solera-23-ans.html">Zacapa 23 Solera</a></li>
# <li class="last"><a title="tous les rhums de la martinique" href="https://www.excellencerhum.com/fr/43-martinique">Rhum martinique</a></li>
# </ul>
# </div>
# <div class="onsalenow">
# <h4>En ce moment</h4>
# <ul>
# <li><a href="https://www.excellencerhum.com/fr/promotions">Promotions et soldes</a></li>
# <li><a href="https://www.excellencerhum.com/fr/69-millesimes-rhum">Millésime de votre âge</a></li>
# <li><a href="https://www.excellencerhum.com/fr/91-idees-cadeaux">Idées cadeaux</a></li>
# <li class="last"><a href="https://www.excellencerhum.com/fr/63-accessoires">Accessoires pour le rhum</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footer_cms_2">
# <div class="main_footer_cms_2">
# <div class="cms_2 footercategory">
# <h4>Votre magasin</h4>
# <ul>
# <li><a href="https://www.excellencerhum.com/fr/mon-compte">Créer son compte</a> / <a href="https://www.excellencerhum.com/fr/mon-compte">Se connecter</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/2-mentions-legales">Mentions légales</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/3-conditions-generales-de-ventes">Conditions generales de ventes</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/13-remerciements-clients">Vos avis et remerciements</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/55-10-raisons-de-nous-faire-confiance">10 raisons de nous faire confiance</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/30-nous-rachetons-vos-bouteilles-futs-et-collections">Nous rachetons vos bouteilles</a></li>
# <li><a href="https://www.excellencerhum.com/fr/contactez-nous">Nous contacter</a></li>
# <li class="last"><a href="https://www.excellencerhum.com/fr/infos/59-rejoignez-nous">Nous recrutons</a></li>
# </ul>
# </div>
# <div class="cms_2 footercategory">
# <h4>Paiements &amp; services pro</h4>
# <ul>
# <li><a href="https://www.excellencerhum.com/fr/infos/51-precommande-d-un-produit">Précommander / Réserver un produit</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/5-paiement-securise-par-carte">Paiements sécurisés</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/22-paiements-cheque-virement">Chèque &amp; Virement</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/14-questions-frequentes-taxes">Taxes &amp; TVA</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/21-cadeaux-clients-collaborateurs">Cadeaux clients &amp; collaborateurs</a></li>
# <li class="last"><a href="https://www.excellencerhum.com/fr/infos/52-bar-hotel-restaurant">Bar, Hôtel, Restaurant</a></li>
# </ul>
# </div>
# <div class="cms_2 footercategory">
# <h4>Livraisons</h4>
# <ul>
# <li><a href="https://www.excellencerhum.com/fr/infos/15-generalite-et-questions">Généralité et Questions</a></li>
# <li><a title="click collect boutique paris" href="https://www.excellencerhum.com/fr/infos/69-click-collect-boutique">Click &amp; Collect à notre boutique</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/16-livraison-point-relais-24h-france">France : Livraison Point Relais 24h</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/18-livraison-a-domicile-24h-france">France : Livraison à domicile 24h</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/19-livraison-europe">Europe : Livraison Chronopost 48h - 72h</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/20-livraison-express-leurope-monde">International / Europe : Livraison Express</a></li>
# <li><a href="https://www.excellencerhum.com/fr/infos/57-livraison-aux-usa">USA : Livraison en 1 à 5 jours</a></li>
# <li class="last"><a href="https://www.excellencerhum.com/fr/infos/58-livraison-canada">Canada : Livraison en 1 à 5 jours</a></li>
# </ul>
# </div>
# <div class="cms_2 social">
# <h4>Besoin d'aide ?</h4>
# <ul>
# <ul>
# <li><span><a href="tel:+33%201%2085%2041%2011%2020">+33 1 85 41 11 20</a></span></li>
# </ul>
# </ul>
# <p>(Appel en France Métropolitaine)</p>
# <p>Du Lundi au Dimanche, de 9h30 à 19h</p>
# <ul>
# <li><a title="Rejoignez-nous sur facebook" href="https://www.facebook.com/Excellencerhum"><img src="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/img/social/active/facebook.png" alt="Rejoignez-nous sur facebook" width="35px" height="35px" /></a></li>
# <li><a title="Suivez nous sur twitter" href="https://twitter.com/ExcellenceRhum"><img src="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/img/social/active/twitter.png" alt="Suivez nous sur twitter" width="35px" height="35px" /></a></li>
# <li><a title="Rejoignez notre cercle sur Google+" href="https://plus.google.com/+ExcellencerhumOfficiel"><img src="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/img/social/active/google.png" alt="Rejoignez notre cercle sur Google+" width="35px" height="35px" /></a></li>
# <li><a title="Visionnez notre chaine YouTube" href="https://www.youtube.com/c/ExcellencerhumOfficiel"><img src="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/img/social/active/youtube.png" alt="Visionnez notre chaine YouTube" width="35px" height="35px" /></a></li>
# <li><a class="last" title="Regardez nos épingles Pinterest" href="https://pinterest.com/ExcellenceRhum/"><img src="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/img/social/active/pinterest.png" alt="Regardez nos épingles Pinterest" width="35px" height="35px" /></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footer_cms_3">
# <div class="footer-all-right">
# <p class="copy">©2020 ExcellenceRhum. Tous droits réservés.<br />L’abus d’alcool est dangereux pour la santé.<br /><em>ExcellenceRhum.com</em> est une marque de <em>NOUMEO SAS</em> une entreprise Française basée à Paris</p>
# <div style="float: right;"><a title="Nos partenaires transporteurs" href="https://www.excellencerhum.com/fr/infos/15-generalite-et-questions"><img style="margin-bottom: 7px;" src="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/img/ship.png" alt="Transports de vos produits" width="435" height="38" /></a><br /> <a title="paiements effectués par Paybox" href="https://www.excellencerhum.com/fr/infos/5-paiement-securise-par-carte"><img src="https://cdn1.excellencerhum.com/themes/ExcellenceRhum/img/pay.png" alt="paiement securisé" width="402" height="19" /></a></div>
# </div>
# </div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 				<script type="text/javascript">
# 					jQuery(document).ready(function(){
# 						var MBG = GoogleAnalyticEnhancedECommerce;
# 						MBG.setCurrency('EUR');
# 						MBG.add({"id":"5187","name":"Collection+2019+-+Maison+La+Mauny+E15+Mill%C3%A9sime+2015","category":"martinique","brand":"Collection+by+ExcellenceRhum","variant":"","type":"typical","position":"0","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fmartinique%2F5187-rhum-agricole-collection-2019-maison-la-mauny-e15-millesime-2015.html","price":"89.00"},'',true);MBG.add({"id":"6081","name":"NAVI+-+Cassiop%C3%A9e","category":"caraibe","brand":"N-A-V-I","variant":"","type":"typical","position":"1","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fcaraibe%2F6081-rhum-navi-cassiopee.html","price":"45.90"},'',true);MBG.add({"id":"6461","name":"NAVI+-+Androm%C3%A8de","category":"caraibe","brand":"N-A-V-I","variant":"","type":"typical","position":"2","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fcaraibe%2F6461-rhum-navi-andromede.html","price":"59.90"},'',true);MBG.add({"id":"6193","name":"Saint+James+-+Brut+de+f%C3%BBt+Mill%C3%A9sime+2003+Batch+2","category":"martinique","brand":"Saint+James","variant":"","type":"typical","position":"3","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fmartinique%2F6193-rhum-agricole-saint-james-brut-de-fut-millesime-2003-batch-2.html","price":"95.00"},'',true);MBG.add({"id":"6008","name":"JM+-+Mill%C3%A9sime+1999+21+ans+Brut+de+f%C3%BBt+Single+Cask","category":"martinique","brand":"Rhum+JM","variant":"","type":"typical","position":"4","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fmartinique%2F6008-rhum-agricole-jm-millesime-1999-21-ans-brut-de-fut-single-cask.html","price":"199.00"},'',true);MBG.add({"id":"6194","name":"JBally+-+Art+D%C3%A9co+Edition+Limit%C3%A9e","category":"martinique","brand":"J.Bally","variant":"","type":"typical","position":"5","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fmartinique%2F6194-rhum-agricole-jbally-art-deco-edition-limitee.html","price":"135.00"},'',true);MBG.add({"id":"6537","name":"Sample+60ml+Saint+James+VSOP","category":"sample-tubes","brand":"Saint+James","variant":"","type":"typical","position":"6","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fsample-tubes%2F6537-sample-60ml-saint-james-vsop.html","price":"5.50"},'',true);MBG.add({"id":"3480","name":"Depaz+-+Hors+d%27age+Mill%C3%A9sime+2002","category":"martinique","brand":"Depaz","variant":"","type":"typical","position":"7","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fmartinique%2F3480-rhum-agricole-depaz-hors-dage-millesime-2002.html","price":"68.00"},'',true);MBG.add({"id":"6538","name":"Sample+60ml+Saint+James+-+Brut+de+colonne+Pure+Canne+Biologique","category":"sample-tubes","brand":"Saint+James","variant":"","type":"typical","position":"8","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fsample-tubes%2F6538-sample-60ml-saint-james-brut-de-colonne-pure-canne-biologique.html","price":"8.15"},'',true);MBG.add({"id":"5756","name":"Depaz+-+Coffret+mignonnettes","category":"martinique","brand":"Depaz","variant":"","type":"typical","position":"9","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fmartinique%2F5756-rhum-agricole-depaz-coffret-mignonnettes.html","price":"24.90"},'',true);MBG.add({"id":"5667","name":"Cl%C3%A9ment+-+Canne+Bleue+2019","category":"martinique","brand":"Clement","variant":"","type":"typical","position":"10","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fmartinique%2F5667-rhum-agricole-clement-canne-bleue-2019.html","price":"35.00"},'',true);MBG.add({"id":"4984","name":"Sample+60ml+La+Favorite+-+La+Digue+2018","category":"sample-tubes","brand":"La+Favorite","variant":"","type":"typical","position":"11","quantity":"1","list":"category","url":"https%3A%2F%2Fwww.excellencerhum.com%2Ffr%2Fsample- ...
# 					});
# 				</script>
#
# 								</div>
# 			</div>
# 		</div>
#
#
#
#
#
#
# 	    <!--Start of Zendesk Chat Script-->
# <script type="text/javascript">
# window.$zopim||(function(d,s){var z=$zopim=function(c){z._.push(c)},$=z.s=
# d.createElement(s),e=d.getElementsByTagName(s)[0];z.set=function(o){z.set.
# _.push(o)};z._=[];z.set._=[];$.async=!0;$.setAttribute("charset","utf-8");
# $.src="https://v2.zopim.com/?1f663U0DN3xa9ndzvkuz1di6mcEO5RzW";z.t=+new Date;$.
# type="text/javascript";e.parentNode.insertBefore($,e)})(document,"script");
# </script>
# <!--End of Zendesk Chat Script-->^y
#
#
#
#
#
#
#
# 	<script src="https://rs.clic2buy.com/retailers/excellence-rhum-delivery-fr.js" async></script>
# 	</body>
# </html>
